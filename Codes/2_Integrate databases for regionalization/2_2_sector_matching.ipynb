# %% [markdown]
# # Sector matching
#
# The matching between ISIC codes in ecoinvent and sectors in exiobase has been done by Simon Roth and Jonas Mehr [1]. This notebook is to check whether the former matching work covers all ISIC codes in ecoinvent v3.7.1 and sectors in exiobase of 2011.
#
#
#
# [1] Jonas Mehr and Simon Roth. Development of a tool refining the regional resolution in life cycle inventory. Project work report, ETH Zürich, 11 2015.

# %%
import numpy as np
import pandas as pd
import pickle
import brightway2 as bw
import re

# %%
# local file
with open('../../Data/sector_matching/sector_matching_dicts.pickle', 'rb') as i:
    matching_dicts = pickle.load(i)
matching_dicts
# Out:
# {'exio_to_isic': {'i28': ['2511',
#    '2512',
#    '2513',
#    '2520',
#    '2591',
#    '2592',
#    '2593',
#    '2599'],
#   'i80': ['8510', '8521', '8522', '8530', '8541', '8542', '8549', '8550'],
#   'i90.6.e': ['3811', '3812', '3821', '3822'],
#   'i40.11.b': ['3510'],
#   'i01.o': ['0150'],
#   'i17': ['1311', '1312', '1313', '1391', '1392', '1393', '1394', '1399'],
#   'i27.42': ['2420'],
#   'i90.6.a': ['3811', '3812', '3821', '3822'],
#   'i90.1.d': ['3811', '3812', '3821', '3822'],
#   'i26.b': ['2393'],
#   'i21.2': ['1702', '1709'],
#   'i90.6.f': ['3811', '3812', '3821', '3822'],
#   'i13.20.13': ['0729'],
#   'i13.20.12': ['0729'],
#   'i90.4.a': ['3811', '3812', '3821', '3822'],
#   'i90.1.b': ['3811', '3812', '3821', '3822'],
#   'i50.b': ['4730'],
#   'i30': ['2610', '2620', '2817'],
#   'i14.3': ['0891', '0892', '0893', '0899', '0990'],
#   'i99': ['9900'],
#   'i13.20.14': ['0729'],
#   'i15.c': ['1010'],
#   'i40.11.l': ['3510'],
#   'i21.1': ['1701'],
#   'i01.j': ['0145', '0150', '0162'],
#   'i22': ['1811', '1812', '1820', '5811', '5812', '5813', '5819'],
#   'i85': ['7500',
#    '8610',
#    '8620',
#    '8690',
#    '8710',
#    '8720',
#    '8730',
#    '8790',
#    '8810',
#    '8890'],
#   'i26.d': ['2394', '2395'],
#   'i24.2': ['2012'],
#   'i15.k': ['1020'],
#   'i16': ['1200'],
#   'i40.11.a': ['3510'],
#   'i15.b': ['1010'],
#   'i33': ['2652', '2660', '2670', '2680'],
#   'i15.f': ['1050'],
#   'i90.6.b': ['3811', '3812', '3821', '3822'],
#   'i90.1.g': ['3811', '3812', '3821', '3822'],
#   'i90.3.a': ['3811', '3812', '3821', '3822'],
#   'i26.a': ['2310'],
#   'i70': ['6810', '6820', '8110'],
#   'i01.n': ['0150'],
#   'i24.1': ['2011', '2013'],
#   'i64': ['5310', '5320', '6110', '6120', '6130', '6190'],
#   'i29': ['2811',
#    '2812',
#    '2813',
#    '2814',
#    '2815',
#    '2816',
#    '2818',
#    '2819',
#    '2821',
#    '2822',
#    '2823',
#    '2824',
#    '2825',
#    '2826',
#    '2829',
#    '3320'],
#   'i27.43': ['2420'],
#   'i01.k': ['0146', '0150', '0162'],
#   'i90.1.f': ['3811', '3812', '3821', '3822'],
#   'i63': ['5210',
#    '5221',
#    '5222',
#    '5223',
#    '5224',
#    '5229',
#    '7911',
#    '7912',
#    '7990'],
#   'i60.3': ['4930'],
#   'i65': ['6411', '6419', '6420', '6430', '6491', '6492', '6499', '7740'],
#   'i66': ['6511', '6512', '6520', '6530'],
#   'i24.3': ['2012', '2021'],
#   'i02': ['0170', '0210', '0220', '0230', '0240'],
#   'i15.i': ['1061', '1062', '1071', '1073', '1074', '1075', '1079', '1080'],
#   'i15.h': ['1072'],
#   'i40.13': ['3510'],
#   'i12': ['0721'],
#   'i40.11.d': ['3510'],
#   'i01.g': ['0116', '0150', '0161', '0163', '0164'],
#   'i90.1.c': ['3811', '3812', '3821', '3822'],
#   'i90.3.b': ['3811', '3812', '3821', '3822'],
#   'i95': ['9700', '9810', '9820'],
#   'i11.b': ['0620', '0910'],
#   'i73': ['7210', '7220'],
#   'i01.a': ['0112', '0150', '0161', '0163', '0164'],
#   'i15.j': ['1101', '1102', '1103', '1104'],
#   'i71': ['7710', '7721', '7722', '7729', '7730'],
#   'i90.6.d': ['3811', '3812', '3821', '3822'],
#   'i14.1': ['0810'],
#   'i26.e': ['2396', '2399'],
#   'i19': ['1511', '1512', '1520'],
#   'i90.5.b': ['3811', '3812', '3821', '3822'],
#   'i34': ['2910', '2920', '2930'],
#   'i01.h': ['0115',
#    '0119',
#    '0127',
#    '0128',
#    '0129',
#    '0130',
#    '0150',
#    '0161',
#    '0163',
#    '0164'],
#   'i23.2': ['1920'],
#   'i26.c': ['2391', '2392'],
#   'i61.1': ['5011', '5012'],
#   'i52': ['3311',
#    '3312',
#    '3313',
#    '3314',
#    '3315',
#    '3319',
#    '4711',
#    '4719',
#    '4721',
#    '4722',
#    '4723',
#    '4741',
#    '4742',
#    '4751',
#    '4752',
#    '4753',
#    '4759',
#    '4761',
#    '4762',
#    '4763',
#    '4764',
#    '4771',
#    '4772',
#    '4773',
#    '4774',
#    '4781',
#    '4782',
#    '4789',
#    '4791',
#    '4799',
#    '9512',
#    '9521',
#    '9522',
#    '9523',
#    '9524',
#    '9529'],
#   'i90.1.e': ['3811', '3812', '3821', '3822'],
#   'i60.1': ['4911', '4912'],
#   'i15.g': ['1061', '1062', '1071', '1075'],
#   'i40.11.e': ['3510'],
#   'i01.m': ['0150', '0162'],
#   'i14.2': ['0810'],
#   'i20': ['1610', '1621', '1622', '1623', '1629'],
#   'i50.a': ['4510', '4520', '4530', '4540'],
#   'i51': ['4610',
#    '4620',
#    '4630',
#    '4641',
#    '4649',
#    '4651',
#    '4652',
#    '4653',
#    '4659',
#    '4661',
#    '4662',
#    '4663',
#    '4669',
#    '4690'],
#   'i62': ['5110', '5120'],
#   'i13.20.11': ['0729'],
#   'i36': ['3100', '3211', '3212', '3220', '3230', '3240', '3250', '3290'],
#   'i01.c': ['0111', '0150', '0161', '0163', '0164'],
#   'i40.3': ['3530'],
#   'i01.l': ['0142', '0143', '0144', '0149', '0150', '0162'],
#   'i01.i': ['0141', '0150', '0162'],
#   'i13.20.16': ['0729'],
#   'i40.11.j': ['3510'],
#   'i27.41': ['2420'],
#   'i11.c': ['0910'],
#   'i72': ['5811',
#    '5812',
#    '5813',
#    '5819',
#    '5820',
#    '6201',
#    '6202',
#    '6209',
#    '631',
#    '6311',
#    '6312',
#    '9511'],
#   'i60.2': ['4921', '4922', '4923'],
#   'i45': ['4100',
#    '4210',
#    '4220',
#    '4290',
#    '4311',
#    '4312',
#    '4321',
#    '4322',
#    '4329',
#    '4330',
#    '4390'],
#   'i90.5.a': ['3811', '3812', '3821', '3822'],
#   'i32': ['2630'],
#   'i90.1.a': ['3811', '3812', '3821', '3822'],
#   'i23.1': ['1910'],
#   'i75': ['8411', '8412', '8413', '8421', '8422', '8423', '8430'],
#   'i40.11.g': ['3510'],
#   'i05': ['0311', '0312', '0321', '0322'],
#   'i40.11.c': ['3510'],
#   'i27.45': ['2420'],
#   'i40.12': ['3510'],
#   'i74': ['6910',
#    '6920',
#    '7010',
#    '7020',
#    '7110',
#    '7120',
#    '7310',
#    '7320',
#    '7410',
#    '7420',
#    '7490',
#    '7810',
#    '7820',
#    '7830',
#    '8010',
#    '8020',
#    '8030',
#    '8121',
#    '8129',
#    '8211',
#    '8219',
#    '8220',
#    '8230',
#    '8291',
#    '8292',
#    '8299'],
#   'i40.11.h': ['3510'],
#   'i40.11.i': ['3510'],
#   'i24.4': ['2011', '2012', '2013', '2022', '2023', '2029', '2030', '2100'],
#   'i23.3': ['3812', '3822'],
#   'i91': ['9411', '9412', '9420', '9491', '9492', '9499'],
#   'i27.44': ['2420'],
#   'i37': ['3830', '3900'],
#   'i15.e': ['1030', '1040'],
#   'i40.11.f': ['3510'],
#   'i40.11.k': ['3510'],
#   'i31': ['2640',
#    '2651',
#    '2710',
#    '2720',
#    '2731',
#    '2732',
#    '2733',
#    '2740',
#    '2750',
#    '2790'],
#   'i01.d': ['0113',
#    '0121',
#    '0122',
#    '0123',
#    '0124',
#    '0125',
#    '0126',
#    '0150',
#    '0161',
#    '0163',
#    '0164'],
#   'i41': ['3600', '3700'],
#   'i13.1': ['0710'],
#   'i61.2': ['5021', '5022'],
#   'i35': ['3011', '3012', '3020', '3030', '3040', '3091', '3092', '3099'],
#   'i27.a': ['2410'],
#   'i01.b': ['0111', '0150', '0161', '0163', '0164'],
#   'i13.20.15': ['0729'],
#   'i92': ['5911',
#    '5912',
#    '5913',
#    '5914',
#    '5920',
#    '6010',
#    '6020',
#    '6391',
#    '8130',
#    '9000',
#    '9101',
#    '9102',
#    '9103',
#    '9200',
#    '9311',
#    '9312',
#    '9319',
#    '9321',
#    '9329'],
#   'i37.w.1': ['3830'],
#   'i90.3.c': ['3811', '3812', '3821', '3822'],
#   'i90.6.c': ['3811', '3812', '3821', '3822'],
#   'i10': ['0510', '0520'],
#   'i11.a': ['0610'],
#   'i90.4.b': ['3811', '3812', '3821', '3822'],
#   'i01.e': ['0111', '0150', '0161', '0163', '0164'],
#   'i18': ['1410', '1420', '1430'],
#   'i93': ['6399', '9601', '9602', '9603', '9609'],
#   'i15.d': ['1010'],
#   'i40.2': ['3520'],
#   'i15.a': ['1010'],
#   'i01.f': ['0114', '0150', '0161', '0163', '0164'],
#   'i27.5': ['2431', '2432'],
#   'i25': ['2211', '2219', '2220'],
#   'i55': ['5510', '5520', '5590', '5610', '5621', '5629', '5630'],
#   'i67': ['6611', '6612', '6619', '6621', '6622', '6629', '6630']},
#  'country_name_dict': {'GB': 'United Kingdom',
#   'WL': 'RoW America',
#   'PL': 'Poland',
#   'EE': 'Estonia',
#   'DE': 'Germany',
#   'SK': 'Slovak Republic',
#   'HU': 'Hungary',
#   'FI': 'Finland',
#   'ID': 'Indonesia',
#   'CH': 'Switzerland',
#   'AT': 'Austria',
#   'MT': 'Malta',
#   'TW': 'Taiwan',
#   'LV': 'Latvia',
#   'WA': 'RoW Asia and Pacific',
#   'ES': 'Spain',
#   'RO': 'Romania',
#   'LT': 'Lithuania',
#   'CY': 'Cyprus',
#   'BR': 'Brazil',
#   'ZA': 'South Africa',
#   'NO': 'Norway',
#   'IN': 'India',
#   'US': 'United States',
#   'IE': 'Ireland',
#   'SE': 'Sweden',
#   'MX': 'Mexico',
#   'GR': 'Greece',
#   'WM': 'RoW Middle East',
#   'CZ': 'Czech Republic',
#   'DK': 'Denmark',
#   'WF': 'RoW Africa',
#   'JP': 'Japan',
#   'CA': 'Canada',
#   'FR': 'France',
#   'KR': 'South Korea',
#   'PT': 'Portugal',
#   'NL': 'Netherlands',
#   'TR': 'Turkey',
#   'BE': 'Belgium',
#   'BG': 'Bulgaria',
#   'WE': 'RoW Europe',
#   'IT': 'Italy',
#   'RU': 'Russian Federation',
#   'CN': 'China',
#   'AU': 'Australia',
#   'SI': 'Slovenia',
#   'LU': 'Luxembourg'},
#  'isic_to_exio': {'2100': ['i24.4'],
#   '2021': ['i24.3'],
#   '2823': ['i29'],
#   '1061': ['i15.i', 'i15.g'],
#   '1080': ['i15.i'],
#   '8110': ['i70'],
#   '6391': ['i92'],
#   '2220': ['i25'],
#   '9511': ['i72'],
#   '3290': ['i36'],
#   '0321': ['i05'],
#   '9420': ['i91'],
#   '3250': ['i36'],
#   '0114': ['i01.f'],
#   '9492': ['i91'],
#   '0210': ['i02'],
#   '8710': ['i85'],
#   '4912': ['i60.1'],
#   '1312': ['i17'],
#   '1420': ['i18'],
#   '9499': ['i91'],
#   '0312': ['i05'],
#   '2652': ['i33'],
#   '7120': ['i74'],
#   '3900': ['i37'],
#   '9103': ['i92'],
#   '1062': ['i15.i', 'i15.g'],
#   '6611': ['i67'],
#   '0164': ['i01.a',
#    'i01.b',
#    'i01.c',
#    'i01.d',
#    'i01.e',
#    'i01.f',
#    'i01.g',
#    'i01.h'],
#   '8030': ['i74'],
#   '4100': ['i45'],
#   '8230': ['i74'],
#   '9412': ['i91'],
#   '2513': ['i28'],
#   '2592': ['i28'],
#   '3311': ['i52'],
#   '2670': ['i33'],
#   '2620': ['i30'],
#   '9319': ['i92'],
#   '0143': ['i01.l'],
#   '5819': ['i22', 'i72'],
#   '4652': ['i51'],
#   '6209': ['i72'],
#   '1311': ['i17'],
#   '1071': ['i15.i', 'i15.g'],
#   '631': ['i72'],
#   '8620': ['i85'],
#   '3821': ['i90.1.a',
#    'i90.1.b',
#    'i90.1.c',
#    'i90.1.d',
#    'i90.1.e',
#    'i90.1.f',
#    'i90.1.g',
#    'i90.3.a',
#    'i90.3.b',
#    'i90.3.c',
#    'i90.4.a',
#    'i90.4.b',
#    'i90.5.a',
#    'i90.5.b',
#    'i90.6.a',
#    'i90.6.b',
#    'i90.6.c',
#    'i90.6.d',
#    'i90.6.e',
#    'i90.6.f'],
#   '7830': ['i74'],
#   '2211': ['i25'],
#   '0112': ['i01.a'],
#   '9102': ['i92'],
#   '3811': ['i90.1.a',
#    'i90.1.b',
#    'i90.1.c',
#    'i90.1.d',
#    'i90.1.e',
#    'i90.1.f',
#    'i90.1.g',
#    'i90.3.a',
#    'i90.3.b',
#    'i90.3.c',
#    'i90.4.a',
#    'i90.4.b',
#    'i90.5.a',
#    'i90.5.b',
#    'i90.6.a',
#    'i90.6.b',
#    'i90.6.c',
#    'i90.6.d',
#    'i90.6.e',
#    'i90.6.f'],
#   '7410': ['i74'],
#   '4789': ['i52'],
#   '2733': ['i31'],
#   '0126': ['i01.d'],
#   '4641': ['i51'],
#   '6619': ['i67'],
#   '1701': ['i21.1'],
#   '9512': ['i52'],
#   '7820': ['i74'],
#   '1709': ['i21.2'],
#   '8129': ['i74'],
#   '6312': ['i72'],
#   '1103': ['i15.j'],
#   '8020': ['i74'],
#   '9312': ['i92'],
#   '6810': ['i70'],
#   '8730': ['i85'],
#   '7911': ['i63'],
#   '6202': ['i72'],
#   '8413': ['i75'],
#   '5811': ['i22', 'i72'],
#   '2520': ['i28'],
#   '8411': ['i75'],
#   '3100': ['i36'],
#   '2790': ['i31'],
#   '1920': ['i23.2'],
#   '9311': ['i92'],
#   '4653': ['i51'],
#   '4764': ['i52'],
#   '1512': ['i19'],
#   '4751': ['i52'],
#   '4911': ['i60.1'],
#   '8550': ['i80'],
#   '8610': ['i85'],
#   '6629': ['i67'],
#   '2740': ['i31'],
#   '9524': ['i52'],
#   '6130': ['i64'],
#   '4923': ['i60.2'],
#   '0891': ['i14.3'],
#   '0220': ['i02'],
#   '0610': ['i11.a'],
#   '1101': ['i15.j'],
#   '2396': ['i26.e'],
#   '5229': ['i63'],
#   '5223': ['i63'],
#   '6492': ['i65'],
#   '9522': ['i52'],
#   '2680': ['i33'],
#   '8299': ['i74'],
#   '0910': ['i11.b', 'i11.c'],
#   '0230': ['i02'],
#   '5320': ['i64'],
#   '0710': ['i13.1'],
#   '8219': ['i74'],
#   '2395': ['i26.d'],
#   '2011': ['i24.1', 'i24.4'],
#   '6622': ['i67'],
#   '6820': ['i70'],
#   '3212': ['i36'],
#   '4663': ['i51'],
#   '2030': ['i24.4'],
#   '2930': ['i34'],
#   '8423': ['i75'],
#   '2710': ['i31'],
#   '6511': ['i66'],
#   '2825': ['i29'],
#   '7990': ['i63'],
#   '7420': ['i74'],
#   '5210': ['i63'],
#   '4762': ['i52'],
#   '2815': ['i29'],
#   '1075': ['i15.i', 'i15.g'],
#   '2393': ['i26.b'],
#   '4772': ['i52'],
#   '8430': ['i75'],
#   '5629': ['i55'],
#   '0144': ['i01.l'],
#   '4651': ['i51'],
#   '2819': ['i29'],
#   '8412': ['i75'],
#   '5011': ['i61.1'],
#   '4781': ['i52'],
#   '4322': ['i45'],
#   '2824': ['i29'],
#   '0116': ['i01.g'],
#   '6190': ['i64'],
#   '0721': ['i12'],
#   '0145': ['i01.j'],
#   '9529': ['i52'],
#   '3312': ['i52'],
#   '5920': ['i92'],
#   '0119': ['i01.h'],
#   '1030': ['i15.e'],
#   '4390': ['i45'],
#   '8220': ['i74'],
#   '5110': ['i62'],
#   '0121': ['i01.d'],
#   '9101': ['i92'],
#   '1020': ['i15.k'],
#   '1102': ['i15.j'],
#   '1702': ['i21.2'],
#   '2420': ['i27.41', 'i27.42', 'i27.43', 'i27.44', 'i27.45'],
#   '9521': ['i52'],
#   '4520': ['i50.a'],
#   '7320': ['i74'],
#   '0510': ['i10'],
#   '2022': ['i24.4'],
#   '0893': ['i14.3'],
#   '7490': ['i74'],
#   '0141': ['i01.i'],
#   '1391': ['i17'],
#   '2630': ['i32'],
#   '1811': ['i22'],
#   '3230': ['i36'],
#   '6491': ['i65'],
#   '3091': ['i35'],
#   '9603': ['i93'],
#   '7810': ['i74'],
#   '2732': ['i31'],
#   '1410': ['i18'],
#   '5630': ['i55'],
#   '4610': ['i51'],
#   '4921': ['i60.2'],
#   '9000': ['i92'],
#   '5022': ['i61.2'],
#   '7010': ['i74'],
#   '6530': ['i66'],
#   '3319': ['i52'],
#   '2816': ['i29'],
#   '4530': ['i50.a'],
#   '2310': ['i26.a'],
#   '9411': ['i91'],
#   '3040': ['i35'],
#   '8790': ['i85'],
#   '5221': ['i63'],
#   '0810': ['i14.1', 'i14.2'],
#   '3320': ['i29'],
#   '8720': ['i85'],
#   '1399': ['i17'],
#   '5520': ['i55'],
#   '0150': ['i01.a',
#    'i01.b',
#    'i01.c',
#    'i01.d',
#    'i01.e',
#    'i01.f',
#    'i01.g',
#    'i01.h',
#    'i01.i',
#    'i01.j',
#    'i01.k',
#    'i01.l',
#    'i01.m',
#    'i01.n',
#    'i01.o'],
#   '2512': ['i28'],
#   '1820': ['i22'],
#   '5120': ['i62'],
#   '0322': ['i05'],
#   '4210': ['i45'],
#   '7721': ['i71'],
#   '8291': ['i74'],
#   '7500': ['i85'],
#   '4330': ['i45'],
#   '4669': ['i51'],
#   '2651': ['i31'],
#   '8690': ['i85'],
#   '6630': ['i67'],
#   '4719': ['i52'],
#   '4791': ['i52'],
#   '4753': ['i52'],
#   '9820': ['i95'],
#   '6120': ['i64'],
#   '2814': ['i29'],
#   '6201': ['i72'],
#   '3520': ['i40.2'],
#   '1079': ['i15.i'],
#   '2920': ['i34'],
#   '8522': ['i80'],
#   '8422': ['i75'],
#   '0990': ['i14.3'],
#   '0162': ['i01.i', 'i01.j', 'i01.k', 'i01.l', 'i01.m'],
#   '0115': ['i01.h'],
#   '7722': ['i71'],
#   '6399': ['i93'],
#   '4723': ['i52'],
#   '2829': ['i29'],
#   '9491': ['i91'],
#   '2660': ['i33'],
#   '3030': ['i35'],
#   '4661': ['i51'],
#   '3530': ['i40.3'],
#   '6910': ['i74'],
#   '6420': ['i65'],
#   '4922': ['i60.2'],
#   '8510': ['i80'],
#   '8890': ['i85'],
#   '1621': ['i20'],
#   '8549': ['i80'],
#   '1072': ['i15.h'],
#   '4649': ['i51'],
#   '4290': ['i45'],
#   '3012': ['i35'],
#   '2826': ['i29'],
#   '2811': ['i29'],
#   '2012': ['i24.2', 'i24.3', 'i24.4'],
#   '2720': ['i31'],
#   '1073': ['i15.i'],
#   '6520': ['i66'],
#   '6499': ['i65'],
#   '9810': ['i95'],
#   '1812': ['i22'],
#   '5510': ['i55'],
#   '0170': ['i02'],
#   '5913': ['i92'],
#   '9700': ['i95'],
#   '2219': ['i25'],
#   '0113': ['i01.d'],
#   '8530': ['i80'],
#   '2750': ['i31'],
#   '9523': ['i52'],
#   '4659': ['i51'],
#   '5820': ['i72'],
#   '9601': ['i93'],
#   '2392': ['i26.c'],
#   '4771': ['i52'],
#   '1313': ['i17'],
#   '9900': ['i99'],
#   '7729': ['i71'],
#   '4540': ['i50.a'],
#   '2391': ['i26.c'],
#   '0520': ['i10'],
#   '4321': ['i45'],
#   '9200': ['i92'],
#   '8211': ['i74'],
#   '0892': ['i14.3'],
#   '5813': ['i22', 'i72'],
#   '4662': ['i51'],
#   '8121': ['i74'],
#   '0125': ['i01.d'],
#   '0128': ['i01.h'],
#   '3314': ['i52'],
#   '7220': ['i73'],
#   '4722': ['i52'],
#   '2818': ['i29'],
#   '0899': ['i14.3'],
#   '0163': ['i01.a',
#    'i01.b',
#    'i01.c',
#    'i01.d',
#    'i01.e',
#    'i01.f',
#    'i01.g',
#    'i01.h'],
#   '5911': ['i92'],
#   '0149': ['i01.l'],
#   '6512': ['i66'],
#   '2394': ['i26.d'],
#   '3822': ['i23.3',
#    'i90.1.a',
#    'i90.1.b',
#    'i90.1.c',
#    'i90.1.d',
#    'i90.1.e',
#    'i90.1.f',
#    'i90.1.g',
#    'i90.3.a',
#    'i90.3.b',
#    'i90.3.c',
#    'i90.4.a',
#    'i90.4.b',
#    'i90.5.a',
#    'i90.5.b',
#    'i90.6.a',
#    'i90.6.b',
#    'i90.6.c',
#    'i90.6.d',
#    'i90.6.e',
#    'i90.6.f'],
#   '6010': ['i92'],
#   '0240': ['i02'],
#   '2399': ['i26.e'],
#   '1074': ['i15.i'],
#   '5621': ['i55'],
#   '4711': ['i52'],
#   '4930': ['i60.3'],
#   '8541': ['i80'],
#   '0142': ['i01.l'],
#   '4620': ['i51'],
#   '3092': ['i35'],
#   '2591': ['i28'],
#   '6621': ['i67'],
#   '4312': ['i45'],
#   '5222': ['i63'],
#   '1629': ['i20'],
#   '2821': ['i29'],
#   '4782': ['i52'],
#   '5914': ['i92'],
#   '2013': ['i24.1', 'i24.4'],
#   '1511': ['i19'],
#   '5912': ['i92'],
#   '7710': ['i71'],
#   '6020': ['i92'],
#   '4759': ['i52'],
#   '3020': ['i35'],
#   '0122': ['i01.d'],
#   '3600': ['i41'],
#   '4630': ['i51'],
#   '3099': ['i35'],
#   '4721': ['i52'],
#   '1622': ['i20'],
#   '1393': ['i17'],
#   '8010': ['i74'],
#   '5590': ['i55'],
#   '6110': ['i64'],
#   '8292': ['i74'],
#   '4311': ['i45'],
#   '1910': ['i23.1'],
#   '0729': ['i13.20.11',
#    'i13.20.12',
#    'i13.20.13',
#    'i13.20.14',
#    'i13.20.15',
#    'i13.20.16'],
#   '2410': ['i27.a'],
#   '4329': ['i45'],
#   '2822': ['i29'],
#   '3011': ['i35'],
#   '3510': ['i40.11.a',
#    'i40.11.b',
#    'i40.11.c',
#    'i40.11.d',
#    'i40.11.e',
#    'i40.11.f',
#    'i40.11.g',
#    'i40.11.h',
#    'i40.11.i',
#    'i40.11.j',
#    'i40.11.k',
#    'i40.11.l',
#    'i40.12',
#    'i40.13'],
#   '5812': ['i22', 'i72'],
#   '3700': ['i41'],
#   '1623': ['i20'],
#   '2593': ['i28'],
#   '0161': ['i01.a',
#    'i01.b',
#    'i01.c',
#    'i01.d',
#    'i01.e',
#    'i01.f',
#    'i01.g',
#    'i01.h'],
#   '1394': ['i17'],
#   '0146': ['i01.k'],
#   '0123': ['i01.d'],
#   '2610': ['i30'],
#   '9321': ['i92'],
#   '2813': ['i29'],
#   '4690': ['i51'],
#   '9602': ['i93'],
#   '2817': ['i30'],
#   '0111': ['i01.b', 'i01.c', 'i01.e'],
#   '3812': ['i23.3',
#    'i90.1.a',
#    'i90.1.b',
#    'i90.1.c',
#    'i90.1.d',
#    'i90.1.e',
#    'i90.1.f',
#    'i90.1.g',
#    'i90.3.a',
#    'i90.3.b',
#    'i90.3.c',
#    'i90.4.a',
#    'i90.4.b',
#    'i90.5.a',
#    'i90.5.b',
#    'i90.6.a',
#    'i90.6.b',
#    'i90.6.c',
#    'i90.6.d',
#    'i90.6.e',
#    'i90.6.f'],
#   '5224': ['i63'],
#   '2731': ['i31'],
#   '3211': ['i36'],
#   '2023': ['i24.4'],
#   '5310': ['i64'],
#   '7210': ['i73'],
#   '1010': ['i15.a', 'i15.b', 'i15.c', 'i15.d'],
#   '1200': ['i16'],
#   '7730': ['i71'],
#   '0129': ['i01.h'],
#   '4761': ['i52'],
#   '7020': ['i74'],
#   '7740': ['i65'],
#   '4730': ['i50.b'],
#   '4742': ['i52'],
#   '0620': ['i11.b'],
#   '8542': ['i80'],
#   '8421': ['i75'],
#   '0127': ['i01.h'],
#   '4763': ['i52'],
#   '8810': ['i85'],
#   '1610': ['i20'],
#   '1050': ['i15.f'],
#   '7110': ['i74'],
#   '2029': ['i24.4'],
#   '2640': ['i31'],
#   '6411': ['i65'],
#   '1392': ['i17'],
#   '4752': ['i52'],
#   '3220': ['i36'],
#   '6612': ['i67'],
#   '2910': ['i34'],
#   '3315': ['i52'],
#   '8521': ['i80'],
#   '6430': ['i65'],
#   '2511': ['i28'],
#   '4510': ['i50.a'],
#   '9329': ['i92'],
#   '7310': ['i74'],
#   '4773': ['i52'],
#   '5610': ['i55'],
#   '3240': ['i36'],
#   '7912': ['i63'],
#   '0311': ['i05'],
#   '2432': ['i27.5'],
#   '4799': ['i52'],
#   '2812': ['i29'],
#   '4220': ['i45'],
#   '9609': ['i93'],
#   '3830': ['i37', 'i37.w.1'],
#   '6311': ['i72'],
#   '1040': ['i15.e'],
#   '5021': ['i61.2'],
#   '0124': ['i01.d'],
#   '4774': ['i52'],
#   '6419': ['i65'],
#   '1520': ['i19'],
#   '8130': ['i92'],
#   '2431': ['i27.5'],
#   '2599': ['i28'],
#   '0130': ['i01.h'],
#   '4741': ['i52'],
#   '5012': ['i61.1'],
#   '6920': ['i74'],
#   '1430': ['i18'],
#   '3313': ['i52'],
#   '1104': ['i15.j']},
#  'exio_name_dict': {'i28': 'Manufacture of fabricated metal products, except machinery and equipment',
#   'i80': 'Education',
#   'i70': 'Real estate activities',
#   'i40.11.b': 'Production of electricity by gas',
#   'i01.o': 'Wool, silk-worm cocoons',
#   'i17': 'Manufacture of textiles',
#   'i52': 'Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods',
#   'i27.42': 'Aluminium production',
#   'i27.42.w': 'Re-processing of secondary aluminium into new aluminium',
#   'i90.6.a': 'Landfill of waste: Food',
#   'i90.1.d': 'Incineration of waste: Metals and Inert materials',
#   'i26.b': 'Manufacture of ceramic goods',
#   'i21.2': 'Paper',
#   'i90.6.f': 'Landfill of waste: Wood',
#   'i01.w.1': 'Manure treatment (conventional), storage and land application',
#   'i27.a.w': 'Re-processing of secondary steel into new steel',
#   'i13.20.12': 'Mining of nickel ores and concentrates',
#   'i90.4.a': 'Composting of food waste, incl. land application',
#   'i66': 'Insurance and pension funding, except compulsory social security',
#   'i50.b': 'Retail sale of automotive fuel',
#   'i30': 'Manufacture of office machinery and computers',
#   'i14.3': 'Mining of chemical and fertilizer minerals, production of salt, other mining and quarrying n.e.c.',
#   'i15.f': 'Processing of dairy products',
#   'i13.20.14': 'Mining of precious metal ores and concentrates',
#   'i15.c': 'Processing of meat poultry',
#   'i40.11.l': 'Production of electricity nec',
#   'i21.1': 'Pulp',
#   'i01.j': 'Pigs farming',
#   'i22': 'Publishing, printing and reproduction of recorded media',
#   'i85': 'Health and social work',
#   'i26.d': 'Manufacture of cement, lime and plaster',
#   'i24.2': 'N-fertiliser',
#   'i15.k': 'Manufacture of fish products',
#   'i16': 'Manufacture of tobacco products',
#   'i40.11.a': 'Production of electricity by coal',
#   'i21.w.1': 'Re-processing of secondary paper into new pulp',
#   'i33': 'Manufacture of medical, precision and optical instruments, watches and clocks',
#   'i15.b': 'Processing of meat pigs',
#   'i65': 'Financial intermediation, except insurance and pension funding',
#   'i26.w.1': 'Re-processing of secondary glass into new glass',
#   'i90.1.g': 'Incineration of waste: Oil/Hazardous waste',
#   'i27.44.w': 'Re-processing of secondary copper into new copper',
#   'i34': 'Manufacture of motor vehicles, trailers and semi-trailers',
#   'i90.1.b': 'Incineration of waste: Paper',
#   'i26.a': 'Manufacture of glass and glass products',
#   'i40.11.i': 'Production of electricity by solar thermal',
#   'i99': 'Extra-territorial organizations and bodies',
#   'i90.6.b': 'Landfill of waste: Paper',
#   'i90.1.a': 'Incineration of waste: Food',
#   'i15.a': 'Processing of meat cattle',
#   'i01.n': 'Raw milk',
#   'i24.1': 'Plastics, basic',
#   'i64': 'Post and telecommunications',
#   'i01.h': 'Cultivation of crops nec',
#   'i27.43': 'Lead, zinc and tin production',
#   'i01.k': 'Poultry farming',
#   'i26.d.w': 'Re-processing of ash into clinker',
#   'i90.1.f': 'Incineration of waste: Wood',
#   'i63': 'Supporting and auxiliary transport activities; activities of travel agencies',
#   'i60.3': 'Transport via pipelines',
#   'i24.3': 'P- and other fertiliser',
#   'i02': 'Forestry, logging and related service activities',
#   'i15.i': 'Processing of Food products nec',
#   'i15.h': 'Sugar refining',
#   'i40.13': 'Distribution and trade of electricity',
#   'i12': 'Mining of uranium and thorium ores',
#   'i13.20.13': 'Mining of aluminium ores and concentrates',
#   'i01.g': 'Cultivation of plant-based fibers',
#   'i90.1.c': 'Incineration of waste: Plastic',
#   'i90.3.b': 'Biogasification of paper, incl. land application',
#   'i95': 'Private households with employed persons',
#   'i90.6.e': 'Landfill of waste: Textiles',
#   'i11.b': 'Extraction of natural gas and services related to natural gas extraction, excluding surveying',
#   'i73': 'Research and development',
#   'i01.a': 'Cultivation of paddy rice',
#   'i27.43.w': 'Re-processing of secondary lead into new lead',
#   'i71': 'Renting of machinery and equipment without operator and of personal and household goods',
#   'i45.w': 'Re-processing of secondary construction material into aggregates',
#   'i01.w.2': 'Manure treatment (biogas), storage and land application',
#   'i26.e': 'Manufacture of other non-metallic mineral products n.e.c.',
#   'i19': 'Tanning and dressing of leather; manufacture of luggage, handbags, saddlery, harness and footwear',
#   'i90.5.b': 'Waste water treatment, other',
#   'i01.e': 'Cultivation of oil seeds',
#   'i27.45.w': 'Re-processing of secondary other non-ferrous metals into new other non-ferrous metals',
#   'i23.2': 'Petroleum Refinery',
#   'i26.c': 'Manufacture of bricks, tiles and construction products, in baked clay',
#   'i61.1': 'Sea and coastal water transport',
#   'i90.5.a': 'Waste water treatment, food',
#   'i40.2': 'Manufacture of gas; distribution of gaseous fuels through mains',
#   'i90.1.e': 'Incineration of waste: Textiles',
#   'i24.1.w': 'Re-processing of secondary plastic into new plastic',
#   'i60.1': 'Transport via railways',
#   'i90.3.a': 'Biogasification of food waste, incl. land application',
#   'i15.g': 'Processed rice',
#   'i40.11.e': 'Production of electricity by wind',
#   'i01.m': 'Animal products nec',
#   'i14.2': 'Quarrying of sand and clay',
#   'i20': 'Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials',
#   'i50.a': 'Sale, maintenance, repair of motor vehicles, motor vehicles parts, motorcycles, motor cycles parts and accessoiries',
#   'i51': 'Wholesale trade and commission trade, except of motor vehicles and motorcycles',
#   'i62': 'Air transport',
#   'i72': 'Computer and related activities',
#   'i36': 'Manufacture of furniture; manufacturing n.e.c.',
#   'i01.c': 'Cultivation of cereal grains nec',
#   'i35': 'Manufacture of other transport equipment',
#   'i01.l': 'Meat animals nec',
#   'i01.i': 'Cattle farming',
#   'i13.20.16': 'Mining of other non-ferrous metal ores and concentrates',
#   'i40.11.j': 'Production of electricity by tide, wave, ocean',
#   'i27.41': 'Precious metals production',
#   'i11.c': 'Extraction, liquefaction, and regasification of other petroleum and gaseous materials',
#   'i60.2': 'Other land transport',
#   'i45': 'Construction',
#   'i37': 'Recycling of waste and scrap',
#   'i32': 'Manufacture of radio, television and communication equipment and apparatus',
#   'i23.3': 'Processing of nuclear fuel',
#   'i23.1': 'Manufacture of coke oven products',
#   'i75': 'Public administration and defence; compulsory social security',
#   'i40.11.g': 'Production of electricity by biomass and waste',
#   'i05': 'Fishing, operating of fish hatcheries and fish farms; service activities incidental to fishing',
#   'i40.11.c': 'Production of electricity by nuclear',
#   'i27.45': 'Other non-ferrous metal production',
#   'i40.12': 'Transmission of electricity',
#   'i74': 'Other business activities',
#   'i40.11.h': 'Production of electricity by solar photovoltaic',
#   'i40.11.d': 'Production of electricity by hydro',
#   'i24.4': 'Chemicals nec',
#   'i90.6.d': 'Landfill of waste: Inert/metal/hazardous',
#   'i91': 'Activities of membership organisation n.e.c.',
#   'i40.3': 'Steam and hot water supply',
#   'i27.44': 'Copper production',
#   'i14.1': 'Quarrying of stone',
#   'i15.e': 'Processing vegetable oils and fats',
#   'i40.11.f': 'Production of electricity by petroleum and other oil derivatives',
#   'i40.11.k': 'Production of electricity by Geothermal',
#   'i31': 'Manufacture of electrical machinery and apparatus n.e.c.',
#   'i01.d': 'Cultivation of vegetables, fruit, nuts',
#   'i41': 'Collection, purification and distribution of water',
#   'i13.1': 'Mining of iron ores',
#   'i61.2': 'Inland water transport',
#   'i13.20.11': 'Mining of copper ores and concentrates',
#   'i27.a': 'Manufacture of basic iron and steel and of ferro-alloys and first products thereof',
#   'i01.b': 'Cultivation of wheat',
#   'i13.20.15': 'Mining of lead, zinc and tin ores and concentrates',
#   'i15.j': 'Manufacture of beverages',
#   'i37.w.1': 'Recycling of bottles by direct reuse',
#   'i90.3.c': 'Biogasification of sewage slugde, incl. land application',
#   'i90.6.c': 'Landfill of waste: Plastic',
#   'i10': 'Mining of coal and lignite; extraction of peat',
#   'i11.a': 'Extraction of crude petroleum and services related to crude oil extraction, excluding surveying',
#   'i90.4.b': 'Composting of paper and wood, incl. land application',
#   'i27.41.w': 'Re-processing of secondary preciuos metals into new preciuos metals',
#   'i18': 'Manufacture of wearing apparel; dressing and dyeing of fur',
#   'i93': 'Other service activities',
#   'i15.d': 'Production of meat products nec',
#   'i92': 'Recreational, cultural and sporting activities',
#   'i20.w': 'Re-processing of secondary wood material into new wood material',
#   'i01.f': 'Cultivation of sugar cane, sugar beet',
#   'i27.5': 'Casting of metals',
#   'i25': 'Manufacture of rubber and plastic products',
#   'i67': 'Activities auxiliary to financial intermediation',
#   'i55': 'Hotels and restaurants',
#   'i29': 'Manufacture of machinery and equipment n.e.c.'}}

# %% [markdown]
# #### 1. Check whether the dictionary covers all sectors of the exiobase in 2011.

# %% [markdown]
# Check sectors covered by current dictionary.

# %%
exio_name_dict = matching_dicts['exio_name_dict']
exio_name_dict = dict(sorted(exio_name_dict.items(), key=lambda item: item[1]))
len(exio_name_dict)
# Out:
# 163

# %%
exio_name = list(exio_name_dict.values())
exio_name
# Out:
# ['Activities auxiliary to financial intermediation',
#  'Activities of membership organisation n.e.c.',
#  'Air transport',
#  'Aluminium production',
#  'Animal products nec',
#  'Biogasification of food waste, incl. land application',
#  'Biogasification of paper, incl. land application',
#  'Biogasification of sewage slugde, incl. land application',
#  'Casting of metals',
#  'Cattle farming',
#  'Chemicals nec',
#  'Collection, purification and distribution of water',
#  'Composting of food waste, incl. land application',
#  'Composting of paper and wood, incl. land application',
#  'Computer and related activities',
#  'Construction',
#  'Copper production',
#  'Cultivation of cereal grains nec',
#  'Cultivation of crops nec',
#  'Cultivation of oil seeds',
#  'Cultivation of paddy rice',
#  'Cultivation of plant-based fibers',
#  'Cultivation of sugar cane, sugar beet',
#  'Cultivation of vegetables, fruit, nuts',
#  'Cultivation of wheat',
#  'Distribution and trade of electricity',
#  'Education',
#  'Extra-territorial organizations and bodies',
#  'Extraction of crude petroleum and services related to crude oil extraction, excluding surveying',
#  'Extraction of natural gas and services related to natural gas extraction, excluding surveying',
#  'Extraction, liquefaction, and regasification of other petroleum and gaseous materials',
#  'Financial intermediation, except insurance and pension funding',
#  'Fishing, operating of fish hatcheries and fish farms; service activities incidental to fishing',
#  'Forestry, logging and related service activities',
#  'Health and social work',
#  'Hotels and restaurants',
#  'Incineration of waste: Food',
#  'Incineration of waste: Metals and Inert materials',
#  'Incineration of waste: Oil/Hazardous waste',
#  'Incineration of waste: Paper',
#  'Incineration of waste: Plastic',
#  'Incineration of waste: Textiles',
#  'Incineration of waste: Wood',
#  'Inland water transport',
#  'Insurance and pension funding, except compulsory social security',
#  'Landfill of waste: Food',
#  'Landfill of waste: Inert/metal/hazardous',
#  'Landfill of waste: Paper',
#  'Landfill of waste: Plastic',
#  'Landfill of waste: Textiles',
#  'Landfill of waste: Wood',
#  'Lead, zinc and tin production',
#  'Manufacture of basic iron and steel and of ferro-alloys and first products thereof',
#  'Manufacture of beverages',
#  'Manufacture of bricks, tiles and construction products, in baked clay',
#  'Manufacture of cement, lime and plaster',
#  'Manufacture of ceramic goods',
#  'Manufacture of coke oven products',
#  'Manufacture of electrical machinery and apparatus n.e.c.',
#  'Manufacture of fabricated metal products, except machinery and equipment',
#  'Manufacture of fish products',
#  'Manufacture of furniture; manufacturing n.e.c.',
#  'Manufacture of gas; distribution of gaseous fuels through mains',
#  'Manufacture of glass and glass products',
#  'Manufacture of machinery and equipment n.e.c.',
#  'Manufacture of medical, precision and optical instruments, watches and clocks',
#  'Manufacture of motor vehicles, trailers and semi-trailers',
#  'Manufacture of office machinery and computers',
#  'Manufacture of other non-metallic mineral products n.e.c.',
#  'Manufacture of other transport equipment',
#  'Manufacture of radio, television and communication equipment and apparatus',
#  'Manufacture of rubber and plastic products',
#  'Manufacture of textiles',
#  'Manufacture of tobacco products',
#  'Manufacture of wearing apparel; dressing and dyeing of fur',
#  'Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials',
#  'Manure treatment (biogas), storage and land application',
#  'Manure treatment (conventional), storage and land application',
#  'Meat animals nec',
#  'Mining of aluminium ores and concentrates',
#  'Mining of chemical and fertilizer minerals, production of salt, other mining and quarrying n.e.c.',
#  'Mining of coal and lignite; extraction of peat',
#  'Mining of copper ores and concentrates',
#  'Mining of iron ores',
#  'Mining of lead, zinc and tin ores and concentrates',
#  'Mining of nickel ores and concentrates',
#  'Mining of other non-ferrous metal ores and concentrates',
#  'Mining of precious metal ores and concentrates',
#  'Mining of uranium and thorium ores',
#  'N-fertiliser',
#  'Other business activities',
#  'Other land transport',
#  'Other non-ferrous metal production',
#  'Other service activities',
#  'P- and other fertiliser',
#  'Paper',
#  'Petroleum Refinery',
#  'Pigs farming',
#  'Plastics, basic',
#  'Post and telecommunications',
#  'Poultry farming',
#  'Precious metals production',
#  'Private households with employed persons',
#  'Processed rice',
#  'Processing of Food products nec',
#  'Processing of dairy products',
#  'Processing of meat cattle',
#  'Processing of meat pigs',
#  'Processing of meat poultry',
#  'Processing of nuclear fuel',
#  'Processing vegetable oils and fats',
#  'Production of electricity by Geothermal',
#  'Production of electricity by biomass and waste',
#  'Production of electricity by coal',
#  'Production of electricity by gas',
#  'Production of electricity by hydro',
#  'Production of electricity by nuclear',
#  'Production of electricity by petroleum and other oil derivatives',
#  'Production of electricity by solar photovoltaic',
#  'Production of electricity by solar thermal',
#  'Production of electricity by tide, wave, ocean',
#  'Production of electricity by wind',
#  'Production of electricity nec',
#  'Production of meat products nec',
#  'Public administration and defence; compulsory social security',
#  'Publishing, printing and reproduction of recorded media',
#  'Pulp',
#  'Quarrying of sand and clay',
#  'Quarrying of stone',
#  'Raw milk',
#  'Re-processing of ash into clinker',
#  'Re-processing of secondary aluminium into new aluminium',
#  'Re-processing of secondary construction material into aggregates',
#  'Re-processing of secondary copper into new copper',
#  'Re-processing of secondary glass into new glass',
#  'Re-processing of secondary lead into new lead',
#  'Re-processing of secondary other non-ferrous metals into new other non-ferrous metals',
#  'Re-processing of secondary paper into new pulp',
#  'Re-processing of secondary plastic into new plastic',
#  'Re-processing of secondary preciuos metals into new preciuos metals',
#  'Re-processing of secondary steel into new steel',
#  'Re-processing of secondary wood material into new wood material',
#  'Real estate activities',
#  'Recreational, cultural and sporting activities',
#  'Recycling of bottles by direct reuse',
#  'Recycling of waste and scrap',
#  'Renting of machinery and equipment without operator and of personal and household goods',
#  'Research and development',
#  'Retail sale of automotive fuel',
#  'Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods',
#  'Sale, maintenance, repair of motor vehicles, motor vehicles parts, motorcycles, motor cycles parts and accessoiries',
#  'Sea and coastal water transport',
#  'Steam and hot water supply',
#  'Sugar refining',
#  'Supporting and auxiliary transport activities; activities of travel agencies',
#  'Tanning and dressing of leather; manufacture of luggage, handbags, saddlery, harness and footwear',
#  'Transmission of electricity',
#  'Transport via pipelines',
#  'Transport via railways',
#  'Waste water treatment, food',
#  'Waste water treatment, other',
#  'Wholesale trade and commission trade, except of motor vehicles and motorcycles',
#  'Wool, silk-worm cocoons']

# %% [markdown]
# Check sectors covered by current exiobase.

# %%
with open('../../Data/lci_iot_imported/iot_flow.p', 'rb') as i:
    iot = pickle.load(i)

iot_sec = {multi_index[1] for multi_index in iot.index}
iot_sec = [sec_name for sec_name in iot_sec] # from set to list where order matters and index can be applied
iot_sec.sort()
iot_sec
# Out:
# ['Activities auxiliary to financial intermediation (67)',
#  'Activities of membership organisation n.e.c. (91)',
#  'Air transport (62)',
#  'Aluminium production',
#  'Animal products nec',
#  'Biogasification of food waste, incl. land application',
#  'Biogasification of paper, incl. land application',
#  'Biogasification of sewage slugde, incl. land application',
#  'Casting of metals',
#  'Cattle farming',
#  'Chemicals nec',
#  'Collection, purification and distribution of water (41)',
#  'Composting of food waste, incl. land application',
#  'Composting of paper and wood, incl. land application',
#  'Computer and related activities (72)',
#  'Construction (45)',
#  'Copper production',
#  'Cultivation of cereal grains nec',
#  'Cultivation of crops nec',
#  'Cultivation of oil seeds',
#  'Cultivation of paddy rice',
#  'Cultivation of plant-based fibers',
#  'Cultivation of sugar cane, sugar beet',
#  'Cultivation of vegetables, fruit, nuts',
#  'Cultivation of wheat',
#  'Distribution and trade of electricity',
#  'Education (80)',
#  'Extra-territorial organizations and bodies',
#  'Extraction of crude petroleum and services related to crude oil extraction, excluding surveying',
#  'Extraction of natural gas and services related to natural gas extraction, excluding surveying',
#  'Extraction, liquefaction, and regasification of other petroleum and gaseous materials',
#  'Financial intermediation, except insurance and pension funding (65)',
#  'Fishing, operating of fish hatcheries and fish farms; service activities incidental to fishing (05)',
#  'Forestry, logging and related service activities (02)',
#  'Health and social work (85)',
#  'Hotels and restaurants (55)',
#  'Incineration of waste: Food',
#  'Incineration of waste: Metals and Inert materials',
#  'Incineration of waste: Oil/Hazardous waste',
#  'Incineration of waste: Paper',
#  'Incineration of waste: Plastic',
#  'Incineration of waste: Textiles',
#  'Incineration of waste: Wood',
#  'Inland water transport',
#  'Insurance and pension funding, except compulsory social security (66)',
#  'Landfill of waste: Food',
#  'Landfill of waste: Inert/metal/hazardous',
#  'Landfill of waste: Paper',
#  'Landfill of waste: Plastic',
#  'Landfill of waste: Textiles',
#  'Landfill of waste: Wood',
#  'Lead, zinc and tin production',
#  'Manufacture of basic iron and steel and of ferro-alloys and first products thereof',
#  'Manufacture of beverages',
#  'Manufacture of bricks, tiles and construction products, in baked clay',
#  'Manufacture of cement, lime and plaster',
#  'Manufacture of ceramic goods',
#  'Manufacture of coke oven products',
#  'Manufacture of electrical machinery and apparatus n.e.c. (31)',
#  'Manufacture of fabricated metal products, except machinery and equipment (28)',
#  'Manufacture of fish products',
#  'Manufacture of furniture; manufacturing n.e.c. (36)',
#  'Manufacture of gas; distribution of gaseous fuels through mains',
#  'Manufacture of glass and glass products',
#  'Manufacture of machinery and equipment n.e.c. (29)',
#  'Manufacture of medical, precision and optical instruments, watches and clocks (33)',
#  'Manufacture of motor vehicles, trailers and semi-trailers (34)',
#  'Manufacture of office machinery and computers (30)',
#  'Manufacture of other non-metallic mineral products n.e.c.',
#  'Manufacture of other transport equipment (35)',
#  'Manufacture of radio, television and communication equipment and apparatus (32)',
#  'Manufacture of rubber and plastic products (25)',
#  'Manufacture of textiles (17)',
#  'Manufacture of tobacco products (16)',
#  'Manufacture of wearing apparel; dressing and dyeing of fur (18)',
#  'Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials (20)',
#  'Manure treatment (biogas), storage and land application',
#  'Manure treatment (conventional), storage and land application',
#  'Meat animals nec',
#  'Mining of aluminium ores and concentrates',
#  'Mining of chemical and fertilizer minerals, production of salt, other mining and quarrying n.e.c.',
#  'Mining of coal and lignite; extraction of peat (10)',
#  'Mining of copper ores and concentrates',
#  'Mining of iron ores',
#  'Mining of lead, zinc and tin ores and concentrates',
#  'Mining of nickel ores and concentrates',
#  'Mining of other non-ferrous metal ores and concentrates',
#  'Mining of precious metal ores and concentrates',
#  'Mining of uranium and thorium ores (12)',
#  'N-fertiliser',
#  'Other business activities (74)',
#  'Other land transport',
#  'Other non-ferrous metal production',
#  'Other service activities (93)',
#  'P- and other fertiliser',
#  'Paper',
#  'Petroleum Refinery',
#  'Pigs farming',
#  'Plastics, basic',
#  'Post and telecommunications (64)',
#  'Poultry farming',
#  'Precious metals production',
#  'Private households with employed persons (95)',
#  'Processed rice',
#  'Processing of Food products nec',
#  'Processing of dairy products',
#  'Processing of meat cattle',
#  'Processing of meat pigs',
#  'Processing of meat poultry',
#  'Processing of nuclear fuel',
#  'Processing vegetable oils and fats',
#  'Production of electricity by Geothermal',
#  'Production of electricity by biomass and waste',
#  'Production of electricity by coal',
#  'Production of electricity by gas',
#  'Production of electricity by hydro',
#  'Production of electricity by nuclear',
#  'Production of electricity by petroleum and other oil derivatives',
#  'Production of electricity by solar photovoltaic',
#  'Production of electricity by solar thermal',
#  'Production of electricity by tide, wave, ocean',
#  'Production of electricity by wind',
#  'Production of electricity nec',
#  'Production of meat products nec',
#  'Public administration and defence; compulsory social security (75)',
#  'Publishing, printing and reproduction of recorded media (22)',
#  'Pulp',
#  'Quarrying of sand and clay',
#  'Quarrying of stone',
#  'Raw milk',
#  'Re-processing of ash into clinker',
#  'Re-processing of secondary aluminium into new aluminium',
#  'Re-processing of secondary construction material into aggregates',
#  'Re-processing of secondary copper into new copper',
#  'Re-processing of secondary glass into new glass',
#  'Re-processing of secondary lead into new lead, zinc and tin',
#  'Re-processing of secondary other non-ferrous metals into new other non-ferrous metals',
#  'Re-processing of secondary paper into new pulp',
#  'Re-processing of secondary plastic into new plastic',
#  'Re-processing of secondary preciuos metals into new preciuos metals',
#  'Re-processing of secondary steel into new steel',
#  'Re-processing of secondary wood material into new wood material',
#  'Real estate activities (70)',
#  'Recreational, cultural and sporting activities (92)',
#  'Recycling of bottles by direct reuse',
#  'Recycling of waste and scrap',
#  'Renting of machinery and equipment without operator and of personal and household goods (71)',
#  'Research and development (73)',
#  'Retail sale of automotive fuel',
#  'Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)',
#  'Sale, maintenance, repair of motor vehicles, motor vehicles parts, motorcycles, motor cycles parts and accessoiries',
#  'Sea and coastal water transport',
#  'Steam and hot water supply',
#  'Sugar refining',
#  'Supporting and auxiliary transport activities; activities of travel agencies (63)',
#  'Tanning and dressing of leather; manufacture of luggage, handbags, saddlery, harness and footwear (19)',
#  'Transmission of electricity',
#  'Transport via pipelines',
#  'Transport via railways',
#  'Waste water treatment, food',
#  'Waste water treatment, other',
#  'Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)',
#  'Wool, silk-worm cocoons']

# %% [markdown]
# Since sectors in current exiobase have (digits) in the end of the sector name, remove them before comparison.

# %%
iot_sec_rev = iot_sec.copy()
for i in range(len(iot_sec_rev)):
    iot_sec_rev[i] = iot_sec_rev[i].replace(' (','').replace(')','')
    iot_sec_rev[i] = re.sub('\d', '', iot_sec_rev[i])
iot_sec_rev.sort()
iot_sec_rev
# Out:
# ['Activities auxiliary to financial intermediation',
#  'Activities of membership organisation n.e.c.',
#  'Air transport',
#  'Aluminium production',
#  'Animal products nec',
#  'Biogasification of food waste, incl. land application',
#  'Biogasification of paper, incl. land application',
#  'Biogasification of sewage slugde, incl. land application',
#  'Casting of metals',
#  'Cattle farming',
#  'Chemicals nec',
#  'Collection, purification and distribution of water',
#  'Composting of food waste, incl. land application',
#  'Composting of paper and wood, incl. land application',
#  'Computer and related activities',
#  'Construction',
#  'Copper production',
#  'Cultivation of cereal grains nec',
#  'Cultivation of crops nec',
#  'Cultivation of oil seeds',
#  'Cultivation of paddy rice',
#  'Cultivation of plant-based fibers',
#  'Cultivation of sugar cane, sugar beet',
#  'Cultivation of vegetables, fruit, nuts',
#  'Cultivation of wheat',
#  'Distribution and trade of electricity',
#  'Education',
#  'Extra-territorial organizations and bodies',
#  'Extraction of crude petroleum and services related to crude oil extraction, excluding surveying',
#  'Extraction of natural gas and services related to natural gas extraction, excluding surveying',
#  'Extraction, liquefaction, and regasification of other petroleum and gaseous materials',
#  'Financial intermediation, except insurance and pension funding',
#  'Fishing, operating of fish hatcheries and fish farms; service activities incidental to fishing',
#  'Forestry, logging and related service activities',
#  'Health and social work',
#  'Hotels and restaurants',
#  'Incineration of waste: Food',
#  'Incineration of waste: Metals and Inert materials',
#  'Incineration of waste: Oil/Hazardous waste',
#  'Incineration of waste: Paper',
#  'Incineration of waste: Plastic',
#  'Incineration of waste: Textiles',
#  'Incineration of waste: Wood',
#  'Inland water transport',
#  'Insurance and pension funding, except compulsory social security',
#  'Landfill of waste: Food',
#  'Landfill of waste: Inert/metal/hazardous',
#  'Landfill of waste: Paper',
#  'Landfill of waste: Plastic',
#  'Landfill of waste: Textiles',
#  'Landfill of waste: Wood',
#  'Lead, zinc and tin production',
#  'Manufacture of basic iron and steel and of ferro-alloys and first products thereof',
#  'Manufacture of beverages',
#  'Manufacture of bricks, tiles and construction products, in baked clay',
#  'Manufacture of cement, lime and plaster',
#  'Manufacture of ceramic goods',
#  'Manufacture of coke oven products',
#  'Manufacture of electrical machinery and apparatus n.e.c.',
#  'Manufacture of fabricated metal products, except machinery and equipment',
#  'Manufacture of fish products',
#  'Manufacture of furniture; manufacturing n.e.c.',
#  'Manufacture of gas; distribution of gaseous fuels through mains',
#  'Manufacture of glass and glass products',
#  'Manufacture of machinery and equipment n.e.c.',
#  'Manufacture of medical, precision and optical instruments, watches and clocks',
#  'Manufacture of motor vehicles, trailers and semi-trailers',
#  'Manufacture of office machinery and computers',
#  'Manufacture of other non-metallic mineral products n.e.c.',
#  'Manufacture of other transport equipment',
#  'Manufacture of radio, television and communication equipment and apparatus',
#  'Manufacture of rubber and plastic products',
#  'Manufacture of textiles',
#  'Manufacture of tobacco products',
#  'Manufacture of wearing apparel; dressing and dyeing of fur',
#  'Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials',
#  'Manure treatmentbiogas, storage and land application',
#  'Manure treatmentconventional, storage and land application',
#  'Meat animals nec',
#  'Mining of aluminium ores and concentrates',
#  'Mining of chemical and fertilizer minerals, production of salt, other mining and quarrying n.e.c.',
#  'Mining of coal and lignite; extraction of peat',
#  'Mining of copper ores and concentrates',
#  'Mining of iron ores',
#  'Mining of lead, zinc and tin ores and concentrates',
#  'Mining of nickel ores and concentrates',
#  'Mining of other non-ferrous metal ores and concentrates',
#  'Mining of precious metal ores and concentrates',
#  'Mining of uranium and thorium ores',
#  'N-fertiliser',
#  'Other business activities',
#  'Other land transport',
#  'Other non-ferrous metal production',
#  'Other service activities',
#  'P- and other fertiliser',
#  'Paper',
#  'Petroleum Refinery',
#  'Pigs farming',
#  'Plastics, basic',
#  'Post and telecommunications',
#  'Poultry farming',
#  'Precious metals production',
#  'Private households with employed persons',
#  'Processed rice',
#  'Processing of Food products nec',
#  'Processing of dairy products',
#  'Processing of meat cattle',
#  'Processing of meat pigs',
#  'Processing of meat poultry',
#  'Processing of nuclear fuel',
#  'Processing vegetable oils and fats',
#  'Production of electricity by Geothermal',
#  'Production of electricity by biomass and waste',
#  'Production of electricity by coal',
#  'Production of electricity by gas',
#  'Production of electricity by hydro',
#  'Production of electricity by nuclear',
#  'Production of electricity by petroleum and other oil derivatives',
#  'Production of electricity by solar photovoltaic',
#  'Production of electricity by solar thermal',
#  'Production of electricity by tide, wave, ocean',
#  'Production of electricity by wind',
#  'Production of electricity nec',
#  'Production of meat products nec',
#  'Public administration and defence; compulsory social security',
#  'Publishing, printing and reproduction of recorded media',
#  'Pulp',
#  'Quarrying of sand and clay',
#  'Quarrying of stone',
#  'Raw milk',
#  'Re-processing of ash into clinker',
#  'Re-processing of secondary aluminium into new aluminium',
#  'Re-processing of secondary construction material into aggregates',
#  'Re-processing of secondary copper into new copper',
#  'Re-processing of secondary glass into new glass',
#  'Re-processing of secondary lead into new lead, zinc and tin',
#  'Re-processing of secondary other non-ferrous metals into new other non-ferrous metals',
#  'Re-processing of secondary paper into new pulp',
#  'Re-processing of secondary plastic into new plastic',
#  'Re-processing of secondary preciuos metals into new preciuos metals',
#  'Re-processing of secondary steel into new steel',
#  'Re-processing of secondary wood material into new wood material',
#  'Real estate activities',
#  'Recreational, cultural and sporting activities',
#  'Recycling of bottles by direct reuse',
#  'Recycling of waste and scrap',
#  'Renting of machinery and equipment without operator and of personal and household goods',
#  'Research and development',
#  'Retail sale of automotive fuel',
#  'Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods',
#  'Sale, maintenance, repair of motor vehicles, motor vehicles parts, motorcycles, motor cycles parts and accessoiries',
#  'Sea and coastal water transport',
#  'Steam and hot water supply',
#  'Sugar refining',
#  'Supporting and auxiliary transport activities; activities of travel agencies',
#  'Tanning and dressing of leather; manufacture of luggage, handbags, saddlery, harness and footwear',
#  'Transmission of electricity',
#  'Transport via pipelines',
#  'Transport via railways',
#  'Waste water treatment, food',
#  'Waste water treatment, other',
#  'Wholesale trade and commission trade, except of motor vehicles and motorcycles',
#  'Wool, silk-worm cocoons']

# %% [markdown]
# Now, compare sectors in the dictionary and the exiobase!

# %%
intersection = set(exio_name) & set(iot_sec_rev)
print(set(exio_name)-intersection)
print(set(iot_sec_rev)-intersection)
# Out:
# {'Re-processing of secondary lead into new lead', 'Manure treatment (biogas), storage and land application', 'Manure treatment (conventional), storage and land application'}
# {'Manure treatmentconventional, storage and land application', 'Manure treatmentbiogas, storage and land application', 'Re-processing of secondary lead into new lead, zinc and tin'}

# %%
for i in range(len(iot_sec_rev)):
    if exio_name[i]!= iot_sec_rev[i]:
        print(iot_sec_rev[i])
        print(exio_name[i])
# Out:
# Manure treatmentbiogas, storage and land application
# Manure treatment (biogas), storage and land application
# Manure treatmentconventional, storage and land application
# Manure treatment (conventional), storage and land application
# Re-processing of secondary lead into new lead, zinc and tin
# Re-processing of secondary lead into new lead

# %% [markdown]
# These three sectors also have updated names but their meanings are not changed. Thus, 163 industries are covered by the dictonary with some revision on their names. Next, update the sector names in the dictonary.

# %%
for ind, (key,value) in enumerate(exio_name_dict.items()):
    exio_name_dict[key]=list(iot_sec)[ind]
matching_dicts['exio_name_dict']= exio_name_dict    
exio_name_dict
# Out:
# {'i67': 'Activities auxiliary to financial intermediation (67)',
#  'i91': 'Activities of membership organisation n.e.c. (91)',
#  'i62': 'Air transport (62)',
#  'i27.42': 'Aluminium production',
#  'i01.m': 'Animal products nec',
#  'i90.3.a': 'Biogasification of food waste, incl. land application',
#  'i90.3.b': 'Biogasification of paper, incl. land application',
#  'i90.3.c': 'Biogasification of sewage slugde, incl. land application',
#  'i27.5': 'Casting of metals',
#  'i01.i': 'Cattle farming',
#  'i24.4': 'Chemicals nec',
#  'i41': 'Collection, purification and distribution of water (41)',
#  'i90.4.a': 'Composting of food waste, incl. land application',
#  'i90.4.b': 'Composting of paper and wood, incl. land application',
#  'i72': 'Computer and related activities (72)',
#  'i45': 'Construction (45)',
#  'i27.44': 'Copper production',
#  'i01.c': 'Cultivation of cereal grains nec',
#  'i01.h': 'Cultivation of crops nec',
#  'i01.e': 'Cultivation of oil seeds',
#  'i01.a': 'Cultivation of paddy rice',
#  'i01.g': 'Cultivation of plant-based fibers',
#  'i01.f': 'Cultivation of sugar cane, sugar beet',
#  'i01.d': 'Cultivation of vegetables, fruit, nuts',
#  'i01.b': 'Cultivation of wheat',
#  'i40.13': 'Distribution and trade of electricity',
#  'i80': 'Education (80)',
#  'i99': 'Extra-territorial organizations and bodies',
#  'i11.a': 'Extraction of crude petroleum and services related to crude oil extraction, excluding surveying',
#  'i11.b': 'Extraction of natural gas and services related to natural gas extraction, excluding surveying',
#  'i11.c': 'Extraction, liquefaction, and regasification of other petroleum and gaseous materials',
#  'i65': 'Financial intermediation, except insurance and pension funding (65)',
#  'i05': 'Fishing, operating of fish hatcheries and fish farms; service activities incidental to fishing (05)',
#  'i02': 'Forestry, logging and related service activities (02)',
#  'i85': 'Health and social work (85)',
#  'i55': 'Hotels and restaurants (55)',
#  'i90.1.a': 'Incineration of waste: Food',
#  'i90.1.d': 'Incineration of waste: Metals and Inert materials',
#  'i90.1.g': 'Incineration of waste: Oil/Hazardous waste',
#  'i90.1.b': 'Incineration of waste: Paper',
#  'i90.1.c': 'Incineration of waste: Plastic',
#  'i90.1.e': 'Incineration of waste: Textiles',
#  'i90.1.f': 'Incineration of waste: Wood',
#  'i61.2': 'Inland water transport',
#  'i66': 'Insurance and pension funding, except compulsory social security (66)',
#  'i90.6.a': 'Landfill of waste: Food',
#  'i90.6.d': 'Landfill of waste: Inert/metal/hazardous',
#  'i90.6.b': 'Landfill of waste: Paper',
#  'i90.6.c': 'Landfill of waste: Plastic',
#  'i90.6.e': 'Landfill of waste: Textiles',
#  'i90.6.f': 'Landfill of waste: Wood',
#  'i27.43': 'Lead, zinc and tin production',
#  'i27.a': 'Manufacture of basic iron and steel and of ferro-alloys and first products thereof',
#  'i15.j': 'Manufacture of beverages',
#  'i26.c': 'Manufacture of bricks, tiles and construction products, in baked clay',
#  'i26.d': 'Manufacture of cement, lime and plaster',
#  'i26.b': 'Manufacture of ceramic goods',
#  'i23.1': 'Manufacture of coke oven products',
#  'i31': 'Manufacture of electrical machinery and apparatus n.e.c. (31)',
#  'i28': 'Manufacture of fabricated metal products, except machinery and equipment (28)',
#  'i15.k': 'Manufacture of fish products',
#  'i36': 'Manufacture of furniture; manufacturing n.e.c. (36)',
#  'i40.2': 'Manufacture of gas; distribution of gaseous fuels through mains',
#  'i26.a': 'Manufacture of glass and glass products',
#  'i29': 'Manufacture of machinery and equipment n.e.c. (29)',
#  'i33': 'Manufacture of medical, precision and optical instruments, watches and clocks (33)',
#  'i34': 'Manufacture of motor vehicles, trailers and semi-trailers (34)',
#  'i30': 'Manufacture of office machinery and computers (30)',
#  'i26.e': 'Manufacture of other non-metallic mineral products n.e.c.',
#  'i35': 'Manufacture of other transport equipment (35)',
#  'i32': 'Manufacture of radio, television and communication equipment and apparatus (32)',
#  'i25': 'Manufacture of rubber and plastic products (25)',
#  'i17': 'Manufacture of textiles (17)',
#  'i16': 'Manufacture of tobacco products (16)',
#  'i18': 'Manufacture of wearing apparel; dressing and dyeing of fur (18)',
#  'i20': 'Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials (20)',
#  'i01.w.2': 'Manure treatment (biogas), storage and land application',
#  'i01.w.1': 'Manure treatment (conventional), storage and land application',
#  'i01.l': 'Meat animals nec',
#  'i13.20.13': 'Mining of aluminium ores and concentrates',
#  'i14.3': 'Mining of chemical and fertilizer minerals, production of salt, other mining and quarrying n.e.c.',
#  'i10': 'Mining of coal and lignite; extraction of peat (10)',
#  'i13.20.11': 'Mining of copper ores and concentrates',
#  'i13.1': 'Mining of iron ores',
#  'i13.20.15': 'Mining of lead, zinc and tin ores and concentrates',
#  'i13.20.12': 'Mining of nickel ores and concentrates',
#  'i13.20.16': 'Mining of other non-ferrous metal ores and concentrates',
#  'i13.20.14': 'Mining of precious metal ores and concentrates',
#  'i12': 'Mining of uranium and thorium ores (12)',
#  'i24.2': 'N-fertiliser',
#  'i74': 'Other business activities (74)',
#  'i60.2': 'Other land transport',
#  'i27.45': 'Other non-ferrous metal production',
#  'i93': 'Other service activities (93)',
#  'i24.3': 'P- and other fertiliser',
#  'i21.2': 'Paper',
#  'i23.2': 'Petroleum Refinery',
#  'i01.j': 'Pigs farming',
#  'i24.1': 'Plastics, basic',
#  'i64': 'Post and telecommunications (64)',
#  'i01.k': 'Poultry farming',
#  'i27.41': 'Precious metals production',
#  'i95': 'Private households with employed persons (95)',
#  'i15.g': 'Processed rice',
#  'i15.i': 'Processing of Food products nec',
#  'i15.f': 'Processing of dairy products',
#  'i15.a': 'Processing of meat cattle',
#  'i15.b': 'Processing of meat pigs',
#  'i15.c': 'Processing of meat poultry',
#  'i23.3': 'Processing of nuclear fuel',
#  'i15.e': 'Processing vegetable oils and fats',
#  'i40.11.k': 'Production of electricity by Geothermal',
#  'i40.11.g': 'Production of electricity by biomass and waste',
#  'i40.11.a': 'Production of electricity by coal',
#  'i40.11.b': 'Production of electricity by gas',
#  'i40.11.d': 'Production of electricity by hydro',
#  'i40.11.c': 'Production of electricity by nuclear',
#  'i40.11.f': 'Production of electricity by petroleum and other oil derivatives',
#  'i40.11.h': 'Production of electricity by solar photovoltaic',
#  'i40.11.i': 'Production of electricity by solar thermal',
#  'i40.11.j': 'Production of electricity by tide, wave, ocean',
#  'i40.11.e': 'Production of electricity by wind',
#  'i40.11.l': 'Production of electricity nec',
#  'i15.d': 'Production of meat products nec',
#  'i75': 'Public administration and defence; compulsory social security (75)',
#  'i22': 'Publishing, printing and reproduction of recorded media (22)',
#  'i21.1': 'Pulp',
#  'i14.2': 'Quarrying of sand and clay',
#  'i14.1': 'Quarrying of stone',
#  'i01.n': 'Raw milk',
#  'i26.d.w': 'Re-processing of ash into clinker',
#  'i27.42.w': 'Re-processing of secondary aluminium into new aluminium',
#  'i45.w': 'Re-processing of secondary construction material into aggregates',
#  'i27.44.w': 'Re-processing of secondary copper into new copper',
#  'i26.w.1': 'Re-processing of secondary glass into new glass',
#  'i27.43.w': 'Re-processing of secondary lead into new lead, zinc and tin',
#  'i27.45.w': 'Re-processing of secondary other non-ferrous metals into new other non-ferrous metals',
#  'i21.w.1': 'Re-processing of secondary paper into new pulp',
#  'i24.1.w': 'Re-processing of secondary plastic into new plastic',
#  'i27.41.w': 'Re-processing of secondary preciuos metals into new preciuos metals',
#  'i27.a.w': 'Re-processing of secondary steel into new steel',
#  'i20.w': 'Re-processing of secondary wood material into new wood material',
#  'i70': 'Real estate activities (70)',
#  'i92': 'Recreational, cultural and sporting activities (92)',
#  'i37.w.1': 'Recycling of bottles by direct reuse',
#  'i37': 'Recycling of waste and scrap',
#  'i71': 'Renting of machinery and equipment without operator and of personal and household goods (71)',
#  'i73': 'Research and development (73)',
#  'i50.b': 'Retail sale of automotive fuel',
#  'i52': 'Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)',
#  'i50.a': 'Sale, maintenance, repair of motor vehicles, motor vehicles parts, motorcycles, motor cycles parts and accessoiries',
#  'i61.1': 'Sea and coastal water transport',
#  'i40.3': 'Steam and hot water supply',
#  'i15.h': 'Sugar refining',
#  'i63': 'Supporting and auxiliary transport activities; activities of travel agencies (63)',
#  'i19': 'Tanning and dressing of leather; manufacture of luggage, handbags, saddlery, harness and footwear (19)',
#  'i40.12': 'Transmission of electricity',
#  'i60.3': 'Transport via pipelines',
#  'i60.1': 'Transport via railways',
#  'i90.5.a': 'Waste water treatment, food',
#  'i90.5.b': 'Waste water treatment, other',
#  'i51': 'Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)',
#  'i01.o': 'Wool, silk-worm cocoons'}

# %% [markdown]
# #### 2. Check whether the ISIC codes in the dictionary cover ISIC codes in ecoinvent v3.7.1

# %% [markdown]
# Check ISIC codes covered by the dictionary.

# %%
ISIC_set = set(matching_dicts['isic_to_exio'].keys())
ISIC_set
# Out:
# {'0111',
#  '0112',
#  '0113',
#  '0114',
#  '0115',
#  '0116',
#  '0119',
#  '0121',
#  '0122',
#  '0123',
#  '0124',
#  '0125',
#  '0126',
#  '0127',
#  '0128',
#  '0129',
#  '0130',
#  '0141',
#  '0142',
#  '0143',
#  '0144',
#  '0145',
#  '0146',
#  '0149',
#  '0150',
#  '0161',
#  '0162',
#  '0163',
#  '0164',
#  '0170',
#  '0210',
#  '0220',
#  '0230',
#  '0240',
#  '0311',
#  '0312',
#  '0321',
#  '0322',
#  '0510',
#  '0520',
#  '0610',
#  '0620',
#  '0710',
#  '0721',
#  '0729',
#  '0810',
#  '0891',
#  '0892',
#  '0893',
#  '0899',
#  '0910',
#  '0990',
#  '1010',
#  '1020',
#  '1030',
#  '1040',
#  '1050',
#  '1061',
#  '1062',
#  '1071',
#  '1072',
#  '1073',
#  '1074',
#  '1075',
#  '1079',
#  '1080',
#  '1101',
#  '1102',
#  '1103',
#  '1104',
#  '1200',
#  '1311',
#  '1312',
#  '1313',
#  '1391',
#  '1392',
#  '1393',
#  '1394',
#  '1399',
#  '1410',
#  '1420',
#  '1430',
#  '1511',
#  '1512',
#  '1520',
#  '1610',
#  '1621',
#  '1622',
#  '1623',
#  '1629',
#  '1701',
#  '1702',
#  '1709',
#  '1811',
#  '1812',
#  '1820',
#  '1910',
#  '1920',
#  '2011',
#  '2012',
#  '2013',
#  '2021',
#  '2022',
#  '2023',
#  '2029',
#  '2030',
#  '2100',
#  '2211',
#  '2219',
#  '2220',
#  '2310',
#  '2391',
#  '2392',
#  '2393',
#  '2394',
#  '2395',
#  '2396',
#  '2399',
#  '2410',
#  '2420',
#  '2431',
#  '2432',
#  '2511',
#  '2512',
#  '2513',
#  '2520',
#  '2591',
#  '2592',
#  '2593',
#  '2599',
#  '2610',
#  '2620',
#  '2630',
#  '2640',
#  '2651',
#  '2652',
#  '2660',
#  '2670',
#  '2680',
#  '2710',
#  '2720',
#  '2731',
#  '2732',
#  '2733',
#  '2740',
#  '2750',
#  '2790',
#  '2811',
#  '2812',
#  '2813',
#  '2814',
#  '2815',
#  '2816',
#  '2817',
#  '2818',
#  '2819',
#  '2821',
#  '2822',
#  '2823',
#  '2824',
#  '2825',
#  '2826',
#  '2829',
#  '2910',
#  '2920',
#  '2930',
#  '3011',
#  '3012',
#  '3020',
#  '3030',
#  '3040',
#  '3091',
#  '3092',
#  '3099',
#  '3100',
#  '3211',
#  '3212',
#  '3220',
#  '3230',
#  '3240',
#  '3250',
#  '3290',
#  '3311',
#  '3312',
#  '3313',
#  '3314',
#  '3315',
#  '3319',
#  '3320',
#  '3510',
#  '3520',
#  '3530',
#  '3600',
#  '3700',
#  '3811',
#  '3812',
#  '3821',
#  '3822',
#  '3830',
#  '3900',
#  '4100',
#  '4210',
#  '4220',
#  '4290',
#  '4311',
#  '4312',
#  '4321',
#  '4322',
#  '4329',
#  '4330',
#  '4390',
#  '4510',
#  '4520',
#  '4530',
#  '4540',
#  '4610',
#  '4620',
#  '4630',
#  '4641',
#  '4649',
#  '4651',
#  '4652',
#  '4653',
#  '4659',
#  '4661',
#  '4662',
#  '4663',
#  '4669',
#  '4690',
#  '4711',
#  '4719',
#  '4721',
#  '4722',
#  '4723',
#  '4730',
#  '4741',
#  '4742',
#  '4751',
#  '4752',
#  '4753',
#  '4759',
#  '4761',
#  '4762',
#  '4763',
#  '4764',
#  '4771',
#  '4772',
#  '4773',
#  '4774',
#  '4781',
#  '4782',
#  '4789',
#  '4791',
#  '4799',
#  '4911',
#  '4912',
#  '4921',
#  '4922',
#  '4923',
#  '4930',
#  '5011',
#  '5012',
#  '5021',
#  '5022',
#  '5110',
#  '5120',
#  '5210',
#  '5221',
#  '5222',
#  '5223',
#  '5224',
#  '5229',
#  '5310',
#  '5320',
#  '5510',
#  '5520',
#  '5590',
#  '5610',
#  '5621',
#  '5629',
#  '5630',
#  '5811',
#  '5812',
#  '5813',
#  '5819',
#  '5820',
#  '5911',
#  '5912',
#  '5913',
#  '5914',
#  '5920',
#  '6010',
#  '6020',
#  '6110',
#  '6120',
#  '6130',
#  '6190',
#  '6201',
#  '6202',
#  '6209',
#  '631',
#  '6311',
#  '6312',
#  '6391',
#  '6399',
#  '6411',
#  '6419',
#  '6420',
#  '6430',
#  '6491',
#  '6492',
#  '6499',
#  '6511',
#  '6512',
#  '6520',
#  '6530',
#  '6611',
#  '6612',
#  '6619',
#  '6621',
#  '6622',
#  '6629',
#  '6630',
#  '6810',
#  '6820',
#  '6910',
#  '6920',
#  '7010',
#  '7020',
#  '7110',
#  '7120',
#  '7210',
#  '7220',
#  '7310',
#  '7320',
#  '7410',
#  '7420',
#  '7490',
#  '7500',
#  '7710',
#  '7721',
#  '7722',
#  '7729',
#  '7730',
#  '7740',
#  '7810',
#  '7820',
#  '7830',
#  '7911',
#  '7912',
#  '7990',
#  '8010',
#  '8020',
#  '8030',
#  '8110',
#  '8121',
#  '8129',
#  '8130',
#  '8211',
#  '8219',
#  '8220',
#  '8230',
#  '8291',
#  '8292',
#  '8299',
#  '8411',
#  '8412',
#  '8413',
#  '8421',
#  '8422',
#  '8423',
#  '8430',
#  '8510',
#  '8521',
#  '8522',
#  '8530',
#  '8541',
#  '8542',
#  '8549',
#  '8550',
#  '8610',
#  '8620',
#  '8690',
#  '8710',
#  '8720',
#  '8730',
#  '8790',
#  '8810',
#  '8890',
#  '9000',
#  '9101',
#  '9102',
#  '9103',
#  '9200',
#  '9311',
#  '9312',
#  '9319',
#  '9321',
#  '9329',
#  '9411',
#  '9412',
#  '9420',
#  '9491',
#  '9492',
#  '9499',
#  '9511',
#  '9512',
#  '9521',
#  '9522',
#  '9523',
#  '9524',
#  '9529',
#  '9601',
#  '9602',
#  '9603',
#  '9609',
#  '9700',
#  '9810',
#  '9820',
#  '9900'}

# %% [markdown]
# Now, try to check the ISIC codes in ecoinvent v3.7.1

# %%
with open('../../Data/lci_iot_imported/cutoff371_data_no_mg.pickle', 'rb') as i:
    datasets = pickle.load(i)
datasets = [d for d in datasets if d['activity type']!='production mix']

# %% [markdown]
# Since burden-free Recycled Content cut-off datasets do not have ISIC code:
# - we choose 3900 as their ISIC code
# - this affects origin shares, but will not affect environmental impact since they are burden free datasets

# %%
for d in datasets:
    if 'Recycled Content' in d['name']:
        d['classifications'].append(('ISIC rev.4 ecoinvent', '3900:Remediation activities and other waste management services'))

for d in datasets:
    if 'Recycled Content' in d['name']:
        print(d['classifications'])
        print(len(d['exchanges']))
        print('------------')

# %%
def extract_isic_code(ds):
#     print(ds['name'])
    cl = ds['classifications']# example of a "classification": [('ISIC rev.4 ecoinvent','1050:Manufacture of dairy products'),('CPC', '22230: Yoghurt and other fermented or acidified milk and cream')],
    isic_info = [c[1] for c in cl if c[0].startswith('ISIC')][0] # only production mixes have no isic-info #1050:
    isic_code = isic_info.split(':')[0] #1050
    isic_code = re.sub(r'\D','', isic_code) # remove added non-digit characters
    return isic_code

ISIC_set_new = set(extract_isic_code(ds) for ds in datasets)

# %%
ISIC_set_not4 = []
for i in ISIC_set_new:
    if i not in ISIC_set:
        ISIC_set_not4.append(i)

ISIC_set_not4.sort()
print(len(ISIC_set_not4))
ISIC_set_not4
# Out:
# 26
# ['012',
#  '014',
#  '03',
#  '032',
#  '051',
#  '072',
#  '09',
#  '108',
#  '131',
#  '170',
#  '19',
#  '20',
#  '23',
#  '239',
#  '242',
#  '243',
#  '25',
#  '259',
#  '27',
#  '28',
#  '35',
#  '38',
#  '381',
#  '382',
#  '49',
#  '68']

# %% [markdown]
# Ecoinvent also provides 3-digits or 2-digits ISIC code, which happens when the activity cannot be precisely classified. <br>
# In this case, ISIC codes with first digits same as them will be used in further calcualtion.

# %% [raw]
# intersection = ISIC_set_new & ISIC_set
# print(len(ISIC_set_new - intersection))
# ISIC_set_new - intersection

# %% [raw]
# # activities with non-4-digits ISIC codes
# for ds in datasets:
#     if len(list(extract_isic_code(ds)))!=4:
#         print(ds['classifications'][0])

# %% [markdown]
# #### 3. Save new matching dictionary

# %%
with open("../../Data/sector_matching/matching_dicts_new.p", 'wb') as o:
    pickle.dump(matching_dicts, o)

# %% [markdown]
# #### 4. Match ISIC code to sector names in exiobase

# %% [markdown]
# In current dictionary, isic code - exiobase sector code - exiobase sector name.

# %%
isic_to_exio = matching_dicts['isic_to_exio']
exio_name_dict = matching_dicts['exio_name_dict']
isic_to_exio_name = {isic:[exio_name_dict[c] for c in exiocode] for isic,exiocode in isic_to_exio.items()}
isic_to_exio_name
# Out:
# {'2100': ['Chemicals nec'],
#  '2021': ['P- and other fertiliser'],
#  '2823': ['Manufacture of machinery and equipment n.e.c. (29)'],
#  '1061': ['Processing of Food products nec', 'Processed rice'],
#  '1080': ['Processing of Food products nec'],
#  '8110': ['Real estate activities (70)'],
#  '6391': ['Recreational, cultural and sporting activities (92)'],
#  '2220': ['Manufacture of rubber and plastic products (25)'],
#  '9511': ['Computer and related activities (72)'],
#  '3290': ['Manufacture of furniture; manufacturing n.e.c. (36)'],
#  '0321': ['Fishing, operating of fish hatcheries and fish farms; service activities incidental to fishing (05)'],
#  '9420': ['Activities of membership organisation n.e.c. (91)'],
#  '3250': ['Manufacture of furniture; manufacturing n.e.c. (36)'],
#  '0114': ['Cultivation of sugar cane, sugar beet'],
#  '9492': ['Activities of membership organisation n.e.c. (91)'],
#  '0210': ['Forestry, logging and related service activities (02)'],
#  '8710': ['Health and social work (85)'],
#  '4912': ['Transport via railways'],
#  '1312': ['Manufacture of textiles (17)'],
#  '1420': ['Manufacture of wearing apparel; dressing and dyeing of fur (18)'],
#  '9499': ['Activities of membership organisation n.e.c. (91)'],
#  '0312': ['Fishing, operating of fish hatcheries and fish farms; service activities incidental to fishing (05)'],
#  '2652': ['Manufacture of medical, precision and optical instruments, watches and clocks (33)'],
#  '7120': ['Other business activities (74)'],
#  '3900': ['Recycling of waste and scrap'],
#  '9103': ['Recreational, cultural and sporting activities (92)'],
#  '1062': ['Processing of Food products nec', 'Processed rice'],
#  '6611': ['Activities auxiliary to financial intermediation (67)'],
#  '0164': ['Cultivation of paddy rice',
#   'Cultivation of wheat',
#   'Cultivation of cereal grains nec',
#   'Cultivation of vegetables, fruit, nuts',
#   'Cultivation of oil seeds',
#   'Cultivation of sugar cane, sugar beet',
#   'Cultivation of plant-based fibers',
#   'Cultivation of crops nec'],
#  '8030': ['Other business activities (74)'],
#  '4100': ['Construction (45)'],
#  '8230': ['Other business activities (74)'],
#  '9412': ['Activities of membership organisation n.e.c. (91)'],
#  '2513': ['Manufacture of fabricated metal products, except machinery and equipment (28)'],
#  '2592': ['Manufacture of fabricated metal products, except machinery and equipment (28)'],
#  '3311': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '2670': ['Manufacture of medical, precision and optical instruments, watches and clocks (33)'],
#  '2620': ['Manufacture of office machinery and computers (30)'],
#  '9319': ['Recreational, cultural and sporting activities (92)'],
#  '0143': ['Meat animals nec'],
#  '5819': ['Publishing, printing and reproduction of recorded media (22)',
#   'Computer and related activities (72)'],
#  '4652': ['Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)'],
#  '6209': ['Computer and related activities (72)'],
#  '1311': ['Manufacture of textiles (17)'],
#  '1071': ['Processing of Food products nec', 'Processed rice'],
#  '631': ['Computer and related activities (72)'],
#  '8620': ['Health and social work (85)'],
#  '3821': ['Incineration of waste: Food',
#   'Incineration of waste: Paper',
#   'Incineration of waste: Plastic',
#   'Incineration of waste: Metals and Inert materials',
#   'Incineration of waste: Textiles',
#   'Incineration of waste: Wood',
#   'Incineration of waste: Oil/Hazardous waste',
#   'Biogasification of food waste, incl. land application',
#   'Biogasification of paper, incl. land application',
#   'Biogasification of sewage slugde, incl. land application',
#   'Composting of food waste, incl. land application',
#   'Composting of paper and wood, incl. land application',
#   'Waste water treatment, food',
#   'Waste water treatment, other',
#   'Landfill of waste: Food',
#   'Landfill of waste: Paper',
#   'Landfill of waste: Plastic',
#   'Landfill of waste: Inert/metal/hazardous',
#   'Landfill of waste: Textiles',
#   'Landfill of waste: Wood'],
#  '7830': ['Other business activities (74)'],
#  '2211': ['Manufacture of rubber and plastic products (25)'],
#  '0112': ['Cultivation of paddy rice'],
#  '9102': ['Recreational, cultural and sporting activities (92)'],
#  '3811': ['Incineration of waste: Food',
#   'Incineration of waste: Paper',
#   'Incineration of waste: Plastic',
#   'Incineration of waste: Metals and Inert materials',
#   'Incineration of waste: Textiles',
#   'Incineration of waste: Wood',
#   'Incineration of waste: Oil/Hazardous waste',
#   'Biogasification of food waste, incl. land application',
#   'Biogasification of paper, incl. land application',
#   'Biogasification of sewage slugde, incl. land application',
#   'Composting of food waste, incl. land application',
#   'Composting of paper and wood, incl. land application',
#   'Waste water treatment, food',
#   'Waste water treatment, other',
#   'Landfill of waste: Food',
#   'Landfill of waste: Paper',
#   'Landfill of waste: Plastic',
#   'Landfill of waste: Inert/metal/hazardous',
#   'Landfill of waste: Textiles',
#   'Landfill of waste: Wood'],
#  '7410': ['Other business activities (74)'],
#  '4789': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '2733': ['Manufacture of electrical machinery and apparatus n.e.c. (31)'],
#  '0126': ['Cultivation of vegetables, fruit, nuts'],
#  '4641': ['Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)'],
#  '6619': ['Activities auxiliary to financial intermediation (67)'],
#  '1701': ['Pulp'],
#  '9512': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '7820': ['Other business activities (74)'],
#  '1709': ['Paper'],
#  '8129': ['Other business activities (74)'],
#  '6312': ['Computer and related activities (72)'],
#  '1103': ['Manufacture of beverages'],
#  '8020': ['Other business activities (74)'],
#  '9312': ['Recreational, cultural and sporting activities (92)'],
#  '6810': ['Real estate activities (70)'],
#  '8730': ['Health and social work (85)'],
#  '7911': ['Supporting and auxiliary transport activities; activities of travel agencies (63)'],
#  '6202': ['Computer and related activities (72)'],
#  '8413': ['Public administration and defence; compulsory social security (75)'],
#  '5811': ['Publishing, printing and reproduction of recorded media (22)',
#   'Computer and related activities (72)'],
#  '2520': ['Manufacture of fabricated metal products, except machinery and equipment (28)'],
#  '8411': ['Public administration and defence; compulsory social security (75)'],
#  '3100': ['Manufacture of furniture; manufacturing n.e.c. (36)'],
#  '2790': ['Manufacture of electrical machinery and apparatus n.e.c. (31)'],
#  '1920': ['Petroleum Refinery'],
#  '9311': ['Recreational, cultural and sporting activities (92)'],
#  '4653': ['Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)'],
#  '4764': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '1512': ['Tanning and dressing of leather; manufacture of luggage, handbags, saddlery, harness and footwear (19)'],
#  '4751': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '4911': ['Transport via railways'],
#  '8550': ['Education (80)'],
#  '8610': ['Health and social work (85)'],
#  '6629': ['Activities auxiliary to financial intermediation (67)'],
#  '2740': ['Manufacture of electrical machinery and apparatus n.e.c. (31)'],
#  '9524': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '6130': ['Post and telecommunications (64)'],
#  '4923': ['Other land transport'],
#  '0891': ['Mining of chemical and fertilizer minerals, production of salt, other mining and quarrying n.e.c.'],
#  '0220': ['Forestry, logging and related service activities (02)'],
#  '0610': ['Extraction of crude petroleum and services related to crude oil extraction, excluding surveying'],
#  '1101': ['Manufacture of beverages'],
#  '2396': ['Manufacture of other non-metallic mineral products n.e.c.'],
#  '5229': ['Supporting and auxiliary transport activities; activities of travel agencies (63)'],
#  '5223': ['Supporting and auxiliary transport activities; activities of travel agencies (63)'],
#  '6492': ['Financial intermediation, except insurance and pension funding (65)'],
#  '9522': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '2680': ['Manufacture of medical, precision and optical instruments, watches and clocks (33)'],
#  '8299': ['Other business activities (74)'],
#  '0910': ['Extraction of natural gas and services related to natural gas extraction, excluding surveying',
#   'Extraction, liquefaction, and regasification of other petroleum and gaseous materials'],
#  '0230': ['Forestry, logging and related service activities (02)'],
#  '5320': ['Post and telecommunications (64)'],
#  '0710': ['Mining of iron ores'],
#  '8219': ['Other business activities (74)'],
#  '2395': ['Manufacture of cement, lime and plaster'],
#  '2011': ['Plastics, basic', 'Chemicals nec'],
#  '6622': ['Activities auxiliary to financial intermediation (67)'],
#  '6820': ['Real estate activities (70)'],
#  '3212': ['Manufacture of furniture; manufacturing n.e.c. (36)'],
#  '4663': ['Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)'],
#  '2030': ['Chemicals nec'],
#  '2930': ['Manufacture of motor vehicles, trailers and semi-trailers (34)'],
#  '8423': ['Public administration and defence; compulsory social security (75)'],
#  '2710': ['Manufacture of electrical machinery and apparatus n.e.c. (31)'],
#  '6511': ['Insurance and pension funding, except compulsory social security (66)'],
#  '2825': ['Manufacture of machinery and equipment n.e.c. (29)'],
#  '7990': ['Supporting and auxiliary transport activities; activities of travel agencies (63)'],
#  '7420': ['Other business activities (74)'],
#  '5210': ['Supporting and auxiliary transport activities; activities of travel agencies (63)'],
#  '4762': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '2815': ['Manufacture of machinery and equipment n.e.c. (29)'],
#  '1075': ['Processing of Food products nec', 'Processed rice'],
#  '2393': ['Manufacture of ceramic goods'],
#  '4772': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '8430': ['Public administration and defence; compulsory social security (75)'],
#  '5629': ['Hotels and restaurants (55)'],
#  '0144': ['Meat animals nec'],
#  '4651': ['Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)'],
#  '2819': ['Manufacture of machinery and equipment n.e.c. (29)'],
#  '8412': ['Public administration and defence; compulsory social security (75)'],
#  '5011': ['Sea and coastal water transport'],
#  '4781': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '4322': ['Construction (45)'],
#  '2824': ['Manufacture of machinery and equipment n.e.c. (29)'],
#  '0116': ['Cultivation of plant-based fibers'],
#  '6190': ['Post and telecommunications (64)'],
#  '0721': ['Mining of uranium and thorium ores (12)'],
#  '0145': ['Pigs farming'],
#  '9529': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '3312': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '5920': ['Recreational, cultural and sporting activities (92)'],
#  '0119': ['Cultivation of crops nec'],
#  '1030': ['Processing vegetable oils and fats'],
#  '4390': ['Construction (45)'],
#  '8220': ['Other business activities (74)'],
#  '5110': ['Air transport (62)'],
#  '0121': ['Cultivation of vegetables, fruit, nuts'],
#  '9101': ['Recreational, cultural and sporting activities (92)'],
#  '1020': ['Manufacture of fish products'],
#  '1102': ['Manufacture of beverages'],
#  '1702': ['Paper'],
#  '2420': ['Precious metals production',
#   'Aluminium production',
#   'Lead, zinc and tin production',
#   'Copper production',
#   'Other non-ferrous metal production'],
#  '9521': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '4520': ['Sale, maintenance, repair of motor vehicles, motor vehicles parts, motorcycles, motor cycles parts and accessoiries'],
#  '7320': ['Other business activities (74)'],
#  '0510': ['Mining of coal and lignite; extraction of peat (10)'],
#  '2022': ['Chemicals nec'],
#  '0893': ['Mining of chemical and fertilizer minerals, production of salt, other mining and quarrying n.e.c.'],
#  '7490': ['Other business activities (74)'],
#  '0141': ['Cattle farming'],
#  '1391': ['Manufacture of textiles (17)'],
#  '2630': ['Manufacture of radio, television and communication equipment and apparatus (32)'],
#  '1811': ['Publishing, printing and reproduction of recorded media (22)'],
#  '3230': ['Manufacture of furniture; manufacturing n.e.c. (36)'],
#  '6491': ['Financial intermediation, except insurance and pension funding (65)'],
#  '3091': ['Manufacture of other transport equipment (35)'],
#  '9603': ['Other service activities (93)'],
#  '7810': ['Other business activities (74)'],
#  '2732': ['Manufacture of electrical machinery and apparatus n.e.c. (31)'],
#  '1410': ['Manufacture of wearing apparel; dressing and dyeing of fur (18)'],
#  '5630': ['Hotels and restaurants (55)'],
#  '4610': ['Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)'],
#  '4921': ['Other land transport'],
#  '9000': ['Recreational, cultural and sporting activities (92)'],
#  '5022': ['Inland water transport'],
#  '7010': ['Other business activities (74)'],
#  '6530': ['Insurance and pension funding, except compulsory social security (66)'],
#  '3319': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '2816': ['Manufacture of machinery and equipment n.e.c. (29)'],
#  '4530': ['Sale, maintenance, repair of motor vehicles, motor vehicles parts, motorcycles, motor cycles parts and accessoiries'],
#  '2310': ['Manufacture of glass and glass products'],
#  '9411': ['Activities of membership organisation n.e.c. (91)'],
#  '3040': ['Manufacture of other transport equipment (35)'],
#  '8790': ['Health and social work (85)'],
#  '5221': ['Supporting and auxiliary transport activities; activities of travel agencies (63)'],
#  '0810': ['Quarrying of stone', 'Quarrying of sand and clay'],
#  '3320': ['Manufacture of machinery and equipment n.e.c. (29)'],
#  '8720': ['Health and social work (85)'],
#  '1399': ['Manufacture of textiles (17)'],
#  '5520': ['Hotels and restaurants (55)'],
#  '0150': ['Cultivation of paddy rice',
#   'Cultivation of wheat',
#   'Cultivation of cereal grains nec',
#   'Cultivation of vegetables, fruit, nuts',
#   'Cultivation of oil seeds',
#   'Cultivation of sugar cane, sugar beet',
#   'Cultivation of plant-based fibers',
#   'Cultivation of crops nec',
#   'Cattle farming',
#   'Pigs farming',
#   'Poultry farming',
#   'Meat animals nec',
#   'Animal products nec',
#   'Raw milk',
#   'Wool, silk-worm cocoons'],
#  '2512': ['Manufacture of fabricated metal products, except machinery and equipment (28)'],
#  '1820': ['Publishing, printing and reproduction of recorded media (22)'],
#  '5120': ['Air transport (62)'],
#  '0322': ['Fishing, operating of fish hatcheries and fish farms; service activities incidental to fishing (05)'],
#  '4210': ['Construction (45)'],
#  '7721': ['Renting of machinery and equipment without operator and of personal and household goods (71)'],
#  '8291': ['Other business activities (74)'],
#  '7500': ['Health and social work (85)'],
#  '4330': ['Construction (45)'],
#  '4669': ['Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)'],
#  '2651': ['Manufacture of electrical machinery and apparatus n.e.c. (31)'],
#  '8690': ['Health and social work (85)'],
#  '6630': ['Activities auxiliary to financial intermediation (67)'],
#  '4719': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '4791': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '4753': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '9820': ['Private households with employed persons (95)'],
#  '6120': ['Post and telecommunications (64)'],
#  '2814': ['Manufacture of machinery and equipment n.e.c. (29)'],
#  '6201': ['Computer and related activities (72)'],
#  '3520': ['Manufacture of gas; distribution of gaseous fuels through mains'],
#  '1079': ['Processing of Food products nec'],
#  '2920': ['Manufacture of motor vehicles, trailers and semi-trailers (34)'],
#  '8522': ['Education (80)'],
#  '8422': ['Public administration and defence; compulsory social security (75)'],
#  '0990': ['Mining of chemical and fertilizer minerals, production of salt, other mining and quarrying n.e.c.'],
#  '0162': ['Cattle farming',
#   'Pigs farming',
#   'Poultry farming',
#   'Meat animals nec',
#   'Animal products nec'],
#  '0115': ['Cultivation of crops nec'],
#  '7722': ['Renting of machinery and equipment without operator and of personal and household goods (71)'],
#  '6399': ['Other service activities (93)'],
#  '4723': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '2829': ['Manufacture of machinery and equipment n.e.c. (29)'],
#  '9491': ['Activities of membership organisation n.e.c. (91)'],
#  '2660': ['Manufacture of medical, precision and optical instruments, watches and clocks (33)'],
#  '3030': ['Manufacture of other transport equipment (35)'],
#  '4661': ['Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)'],
#  '3530': ['Steam and hot water supply'],
#  '6910': ['Other business activities (74)'],
#  '6420': ['Financial intermediation, except insurance and pension funding (65)'],
#  '4922': ['Other land transport'],
#  '8510': ['Education (80)'],
#  '8890': ['Health and social work (85)'],
#  '1621': ['Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials (20)'],
#  '8549': ['Education (80)'],
#  '1072': ['Sugar refining'],
#  '4649': ['Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)'],
#  '4290': ['Construction (45)'],
#  '3012': ['Manufacture of other transport equipment (35)'],
#  '2826': ['Manufacture of machinery and equipment n.e.c. (29)'],
#  '2811': ['Manufacture of machinery and equipment n.e.c. (29)'],
#  '2012': ['N-fertiliser', 'P- and other fertiliser', 'Chemicals nec'],
#  '2720': ['Manufacture of electrical machinery and apparatus n.e.c. (31)'],
#  '1073': ['Processing of Food products nec'],
#  '6520': ['Insurance and pension funding, except compulsory social security (66)'],
#  '6499': ['Financial intermediation, except insurance and pension funding (65)'],
#  '9810': ['Private households with employed persons (95)'],
#  '1812': ['Publishing, printing and reproduction of recorded media (22)'],
#  '5510': ['Hotels and restaurants (55)'],
#  '0170': ['Forestry, logging and related service activities (02)'],
#  '5913': ['Recreational, cultural and sporting activities (92)'],
#  '9700': ['Private households with employed persons (95)'],
#  '2219': ['Manufacture of rubber and plastic products (25)'],
#  '0113': ['Cultivation of vegetables, fruit, nuts'],
#  '8530': ['Education (80)'],
#  '2750': ['Manufacture of electrical machinery and apparatus n.e.c. (31)'],
#  '9523': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '4659': ['Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)'],
#  '5820': ['Computer and related activities (72)'],
#  '9601': ['Other service activities (93)'],
#  '2392': ['Manufacture of bricks, tiles and construction products, in baked clay'],
#  '4771': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '1313': ['Manufacture of textiles (17)'],
#  '9900': ['Extra-territorial organizations and bodies'],
#  '7729': ['Renting of machinery and equipment without operator and of personal and household goods (71)'],
#  '4540': ['Sale, maintenance, repair of motor vehicles, motor vehicles parts, motorcycles, motor cycles parts and accessoiries'],
#  '2391': ['Manufacture of bricks, tiles and construction products, in baked clay'],
#  '0520': ['Mining of coal and lignite; extraction of peat (10)'],
#  '4321': ['Construction (45)'],
#  '9200': ['Recreational, cultural and sporting activities (92)'],
#  '8211': ['Other business activities (74)'],
#  '0892': ['Mining of chemical and fertilizer minerals, production of salt, other mining and quarrying n.e.c.'],
#  '5813': ['Publishing, printing and reproduction of recorded media (22)',
#   'Computer and related activities (72)'],
#  '4662': ['Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)'],
#  '8121': ['Other business activities (74)'],
#  '0125': ['Cultivation of vegetables, fruit, nuts'],
#  '0128': ['Cultivation of crops nec'],
#  '3314': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '7220': ['Research and development (73)'],
#  '4722': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '2818': ['Manufacture of machinery and equipment n.e.c. (29)'],
#  '0899': ['Mining of chemical and fertilizer minerals, production of salt, other mining and quarrying n.e.c.'],
#  '0163': ['Cultivation of paddy rice',
#   'Cultivation of wheat',
#   'Cultivation of cereal grains nec',
#   'Cultivation of vegetables, fruit, nuts',
#   'Cultivation of oil seeds',
#   'Cultivation of sugar cane, sugar beet',
#   'Cultivation of plant-based fibers',
#   'Cultivation of crops nec'],
#  '5911': ['Recreational, cultural and sporting activities (92)'],
#  '0149': ['Meat animals nec'],
#  '6512': ['Insurance and pension funding, except compulsory social security (66)'],
#  '2394': ['Manufacture of cement, lime and plaster'],
#  '3822': ['Processing of nuclear fuel',
#   'Incineration of waste: Food',
#   'Incineration of waste: Paper',
#   'Incineration of waste: Plastic',
#   'Incineration of waste: Metals and Inert materials',
#   'Incineration of waste: Textiles',
#   'Incineration of waste: Wood',
#   'Incineration of waste: Oil/Hazardous waste',
#   'Biogasification of food waste, incl. land application',
#   'Biogasification of paper, incl. land application',
#   'Biogasification of sewage slugde, incl. land application',
#   'Composting of food waste, incl. land application',
#   'Composting of paper and wood, incl. land application',
#   'Waste water treatment, food',
#   'Waste water treatment, other',
#   'Landfill of waste: Food',
#   'Landfill of waste: Paper',
#   'Landfill of waste: Plastic',
#   'Landfill of waste: Inert/metal/hazardous',
#   'Landfill of waste: Textiles',
#   'Landfill of waste: Wood'],
#  '6010': ['Recreational, cultural and sporting activities (92)'],
#  '0240': ['Forestry, logging and related service activities (02)'],
#  '2399': ['Manufacture of other non-metallic mineral products n.e.c.'],
#  '1074': ['Processing of Food products nec'],
#  '5621': ['Hotels and restaurants (55)'],
#  '4711': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '4930': ['Transport via pipelines'],
#  '8541': ['Education (80)'],
#  '0142': ['Meat animals nec'],
#  '4620': ['Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)'],
#  '3092': ['Manufacture of other transport equipment (35)'],
#  '2591': ['Manufacture of fabricated metal products, except machinery and equipment (28)'],
#  '6621': ['Activities auxiliary to financial intermediation (67)'],
#  '4312': ['Construction (45)'],
#  '5222': ['Supporting and auxiliary transport activities; activities of travel agencies (63)'],
#  '1629': ['Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials (20)'],
#  '2821': ['Manufacture of machinery and equipment n.e.c. (29)'],
#  '4782': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '5914': ['Recreational, cultural and sporting activities (92)'],
#  '2013': ['Plastics, basic', 'Chemicals nec'],
#  '1511': ['Tanning and dressing of leather; manufacture of luggage, handbags, saddlery, harness and footwear (19)'],
#  '5912': ['Recreational, cultural and sporting activities (92)'],
#  '7710': ['Renting of machinery and equipment without operator and of personal and household goods (71)'],
#  '6020': ['Recreational, cultural and sporting activities (92)'],
#  '4759': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '3020': ['Manufacture of other transport equipment (35)'],
#  '0122': ['Cultivation of vegetables, fruit, nuts'],
#  '3600': ['Collection, purification and distribution of water (41)'],
#  '4630': ['Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)'],
#  '3099': ['Manufacture of other transport equipment (35)'],
#  '4721': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '1622': ['Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials (20)'],
#  '1393': ['Manufacture of textiles (17)'],
#  '8010': ['Other business activities (74)'],
#  '5590': ['Hotels and restaurants (55)'],
#  '6110': ['Post and telecommunications (64)'],
#  '8292': ['Other business activities (74)'],
#  '4311': ['Construction (45)'],
#  '1910': ['Manufacture of coke oven products'],
#  '0729': ['Mining of copper ores and concentrates',
#   'Mining of nickel ores and concentrates',
#   'Mining of aluminium ores and concentrates',
#   'Mining of precious metal ores and concentrates',
#   'Mining of lead, zinc and tin ores and concentrates',
#   'Mining of other non-ferrous metal ores and concentrates'],
#  '2410': ['Manufacture of basic iron and steel and of ferro-alloys and first products thereof'],
#  '4329': ['Construction (45)'],
#  '2822': ['Manufacture of machinery and equipment n.e.c. (29)'],
#  '3011': ['Manufacture of other transport equipment (35)'],
#  '3510': ['Production of electricity by coal',
#   'Production of electricity by gas',
#   'Production of electricity by nuclear',
#   'Production of electricity by hydro',
#   'Production of electricity by wind',
#   'Production of electricity by petroleum and other oil derivatives',
#   'Production of electricity by biomass and waste',
#   'Production of electricity by solar photovoltaic',
#   'Production of electricity by solar thermal',
#   'Production of electricity by tide, wave, ocean',
#   'Production of electricity by Geothermal',
#   'Production of electricity nec',
#   'Transmission of electricity',
#   'Distribution and trade of electricity'],
#  '5812': ['Publishing, printing and reproduction of recorded media (22)',
#   'Computer and related activities (72)'],
#  '3700': ['Collection, purification and distribution of water (41)'],
#  '1623': ['Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials (20)'],
#  '2593': ['Manufacture of fabricated metal products, except machinery and equipment (28)'],
#  '0161': ['Cultivation of paddy rice',
#   'Cultivation of wheat',
#   'Cultivation of cereal grains nec',
#   'Cultivation of vegetables, fruit, nuts',
#   'Cultivation of oil seeds',
#   'Cultivation of sugar cane, sugar beet',
#   'Cultivation of plant-based fibers',
#   'Cultivation of crops nec'],
#  '1394': ['Manufacture of textiles (17)'],
#  '0146': ['Poultry farming'],
#  '0123': ['Cultivation of vegetables, fruit, nuts'],
#  '2610': ['Manufacture of office machinery and computers (30)'],
#  '9321': ['Recreational, cultural and sporting activities (92)'],
#  '2813': ['Manufacture of machinery and equipment n.e.c. (29)'],
#  '4690': ['Wholesale trade and commission trade, except of motor vehicles and motorcycles (51)'],
#  '9602': ['Other service activities (93)'],
#  '2817': ['Manufacture of office machinery and computers (30)'],
#  '0111': ['Cultivation of wheat',
#   'Cultivation of cereal grains nec',
#   'Cultivation of oil seeds'],
#  '3812': ['Processing of nuclear fuel',
#   'Incineration of waste: Food',
#   'Incineration of waste: Paper',
#   'Incineration of waste: Plastic',
#   'Incineration of waste: Metals and Inert materials',
#   'Incineration of waste: Textiles',
#   'Incineration of waste: Wood',
#   'Incineration of waste: Oil/Hazardous waste',
#   'Biogasification of food waste, incl. land application',
#   'Biogasification of paper, incl. land application',
#   'Biogasification of sewage slugde, incl. land application',
#   'Composting of food waste, incl. land application',
#   'Composting of paper and wood, incl. land application',
#   'Waste water treatment, food',
#   'Waste water treatment, other',
#   'Landfill of waste: Food',
#   'Landfill of waste: Paper',
#   'Landfill of waste: Plastic',
#   'Landfill of waste: Inert/metal/hazardous',
#   'Landfill of waste: Textiles',
#   'Landfill of waste: Wood'],
#  '5224': ['Supporting and auxiliary transport activities; activities of travel agencies (63)'],
#  '2731': ['Manufacture of electrical machinery and apparatus n.e.c. (31)'],
#  '3211': ['Manufacture of furniture; manufacturing n.e.c. (36)'],
#  '2023': ['Chemicals nec'],
#  '5310': ['Post and telecommunications (64)'],
#  '7210': ['Research and development (73)'],
#  '1010': ['Processing of meat cattle',
#   'Processing of meat pigs',
#   'Processing of meat poultry',
#   'Production of meat products nec'],
#  '1200': ['Manufacture of tobacco products (16)'],
#  '7730': ['Renting of machinery and equipment without operator and of personal and household goods (71)'],
#  '0129': ['Cultivation of crops nec'],
#  '4761': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '7020': ['Other business activities (74)'],
#  '7740': ['Financial intermediation, except insurance and pension funding (65)'],
#  '4730': ['Retail sale of automotive fuel'],
#  '4742': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '0620': ['Extraction of natural gas and services related to natural gas extraction, excluding surveying'],
#  '8542': ['Education (80)'],
#  '8421': ['Public administration and defence; compulsory social security (75)'],
#  '0127': ['Cultivation of crops nec'],
#  '4763': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '8810': ['Health and social work (85)'],
#  '1610': ['Manufacture of wood and of products of wood and cork, except furniture; manufacture of articles of straw and plaiting materials (20)'],
#  '1050': ['Processing of dairy products'],
#  '7110': ['Other business activities (74)'],
#  '2029': ['Chemicals nec'],
#  '2640': ['Manufacture of electrical machinery and apparatus n.e.c. (31)'],
#  '6411': ['Financial intermediation, except insurance and pension funding (65)'],
#  '1392': ['Manufacture of textiles (17)'],
#  '4752': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '3220': ['Manufacture of furniture; manufacturing n.e.c. (36)'],
#  '6612': ['Activities auxiliary to financial intermediation (67)'],
#  '2910': ['Manufacture of motor vehicles, trailers and semi-trailers (34)'],
#  '3315': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '8521': ['Education (80)'],
#  '6430': ['Financial intermediation, except insurance and pension funding (65)'],
#  '2511': ['Manufacture of fabricated metal products, except machinery and equipment (28)'],
#  '4510': ['Sale, maintenance, repair of motor vehicles, motor vehicles parts, motorcycles, motor cycles parts and accessoiries'],
#  '9329': ['Recreational, cultural and sporting activities (92)'],
#  '7310': ['Other business activities (74)'],
#  '4773': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '5610': ['Hotels and restaurants (55)'],
#  '3240': ['Manufacture of furniture; manufacturing n.e.c. (36)'],
#  '7912': ['Supporting and auxiliary transport activities; activities of travel agencies (63)'],
#  '0311': ['Fishing, operating of fish hatcheries and fish farms; service activities incidental to fishing (05)'],
#  '2432': ['Casting of metals'],
#  '4799': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '2812': ['Manufacture of machinery and equipment n.e.c. (29)'],
#  '4220': ['Construction (45)'],
#  '9609': ['Other service activities (93)'],
#  '3830': ['Recycling of waste and scrap',
#   'Recycling of bottles by direct reuse'],
#  '6311': ['Computer and related activities (72)'],
#  '1040': ['Processing vegetable oils and fats'],
#  '5021': ['Inland water transport'],
#  '0124': ['Cultivation of vegetables, fruit, nuts'],
#  '4774': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '6419': ['Financial intermediation, except insurance and pension funding (65)'],
#  '1520': ['Tanning and dressing of leather; manufacture of luggage, handbags, saddlery, harness and footwear (19)'],
#  '8130': ['Recreational, cultural and sporting activities (92)'],
#  '2431': ['Casting of metals'],
#  '2599': ['Manufacture of fabricated metal products, except machinery and equipment (28)'],
#  '0130': ['Cultivation of crops nec'],
#  '4741': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '5012': ['Sea and coastal water transport'],
#  '6920': ['Other business activities (74)'],
#  '1430': ['Manufacture of wearing apparel; dressing and dyeing of fur (18)'],
#  '3313': ['Retail trade, except of motor vehicles and motorcycles; repair of personal and household goods (52)'],
#  '1104': ['Manufacture of beverages']}

# %%
with open("../../Data/sector_matching/isic_TO_exio_name.p", 'wb') as o:
    pickle.dump(isic_to_exio_name, o)
