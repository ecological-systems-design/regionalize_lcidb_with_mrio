# %% [markdown]
# # Introduction
#
# This notebook uses PV panel production as an example to show how to implement regionalized version of ecoinvent in LCA studies.

# %% [markdown]
# # Table of content <a id='back'></a>
#
#    <a href='#import'>Preparation: Import packages and files; prepare indexes for tracing contributors</a> <br>
#
# 1. <a href='#step1'>How to do LCA calculation? </a> <br>
# 2. <a href='#step2'>How to get country or sector contributions to total impact? </a> <br>
# 3. <a href='#step3'>How to dig deeper and find out key processes and locations? </a> <br>
# 4. <a href='#step4'>How to trace the country-level consumption mixes of products based on IOT? </a> <br>

# %% [markdown]
# ## Preparation: Import packages and files; prepare indexes for tracing contributors <a id='import'></a> <br>
#  <a href='#back'>back</a>

# %%
import os
import pickle
import collections
import operator
import time
import itertools
import textwrap

import brightway2 as bw
import numpy as np
import scipy.sparse as sp
import pypardiso as pp
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import ticker
import seaborn as sns 
# %matplotlib inline

import geopandas as gpd
import matplotlib as mpl

# %%
with open('../../Data/final_matrix/full_index.p', 'rb') as i:
    full_index = pickle.load(i)
with open('../../Data/final_matrix/technosphere_matrix.p', 'rb') as i:
    tec_mat = pickle.load(i)
with open('../../Data/final_matrix/biosphere_index.p', 'rb') as i:
    bio_index = pickle.load(i)
with open('../../Data/final_matrix/biosphere_matrix_csc.p', 'rb') as i:
    bio_mat = pickle.load(i)

# %%
cfs_dict = {}
with open('../../Data/final_matrix/CF_aware_glo.p', 'rb') as i:
    cfs_dict['aware_glo'] = pd.read_pickle(i)
with open('../../Data/final_matrix/CF_aware.p', 'rb') as i:
    cfs_dict['aware_reg'] = pd.read_pickle(i)
with open('../../Data/final_matrix/CF_ipcc.p', 'rb') as i:
    cfs_dict['ipcc'] = pd.read_pickle(i)

# %%
cfs_ei_dict = {}
with open('../../Data/final_matrix/CF_aware_glo_eco.p', 'rb') as i:
    cfs_ei_dict['aware_glo_ei'] = pd.read_pickle(i)

# %%
with open('../../Data/tech_vector/full_reference_dataset_dict.p', 'rb') as i: #{full_index: code of ref ds}
    ref_ds_dict = pickle.load(i)
inv_ref_ds_dict = collections.defaultdict(dict)
for full_i, ref_ds in ref_ds_dict.items():
    inv_ref_ds_dict[ref_ds][full_i[0]] = full_i
inv_ref_ds_dict = dict(inv_ref_ds_dict) #{code:{reg: (reg, mr_key)}}

with open('../../Data/tech_vector/mr_key_MRD.p', 'rb') as i:
    mr_key_MRD = pickle.load(i)

# %%
with open('../../Data/region_matching/iot_co.p', 'rb') as i:
    iot_co = pickle.load(i)
with open('../../Data/processed_data/iot_flow.p', 'rb') as i:
    iot = pickle.load(i)
iot_sectors = np.array(iot.index.levels[1])

# %%
with open('../../Data/sector_matching/isic_TO_exio_name.p', 'rb') as i:
    isic_TO_exio_name = pickle.load(i)
with open('../../Data/tech_vector/datasets_no_prodmix_with_new_items.p', 'rb') as i:
    datasets = pickle.load(i)

# %%
# %%time
bw.projects.set_current('regeco')
bw.projects.current
db = bw.Database('ecoinvent 3.7.1_cutoff_ecoSpold02')
# Out:
# CPU times: user 40.7 ms, sys: 12.5 ms, total: 53.2 ms
# Wall time: 141 ms

# %% [markdown]
# Based on the full index list which characterizes datasets in new ecoinvent and descbribes rows and columns of technosphere matrix, we generate corresponding country list, isic sector list, dataset name list, reference product list, unit list, and reference dataset location list. These lists are used for contribution analysis based on characterized inventory matrix in the future.

# %%
full_index_country = [(i[0][:2],i[1]) if i[0] != 'Canada without Quebec' else ('CA',i[1])  for i in full_index]
with open('../data/lcia_case_studies/full_index_country.p', 'wb') as o:
    pickle.dump(full_index_country, o)

# %%
# isic sector list
# match isic code in datasets to exio sectors index, create a dictionary {exio sectors index: isic code}
with open('../data/sector_matching/isic_TO_exio_name.p', 'rb') as i:
    isic_TO_exio_name = pickle.load(i)
with open('../data/tech_vector/datasets_no_prodmix_with_new_items.p', 'rb') as i:
    datasets = pickle.load(i)

iot_sectors_noarray = iot.index.levels[1]
def match_isic_code_TO_exio_sectors(isic_code):
    if isic_code in isic_TO_exio_name.keys():
        exio_sec_name = isic_TO_exio_name[isic_code]
    else:
        possible_full_isic_codes = [code for code in isic_TO_exio_name.keys() if code.startswith(isic_code)]
        exio_sec_name = list({sector for sector in 
                        itertools.chain.from_iterable([isic_TO_exio_name[c] for c in possible_full_isic_codes])})
    iot_sec_indexer = iot_sectors_noarray.get_indexer(exio_sec_name) # return an array, an activity - several sectors in exio
    return sorted(iot_sec_indexer)

iot_sec_indexer_TO_isic_code = {}
for ds in datasets:
    iot_sec_indexer_TO_isic_code[tuple(match_isic_code_TO_exio_sectors(ds['ISIC code']))] = ds['ISIC code']

with open('../data/lcia_case_studies/iot_sec_indexer_TO_isic_code.p', 'wb') as o:
    pickle.dump(iot_sec_indexer_TO_isic_code, o)

# isic code to name
isic_code_to_name = {}
for ds in datasets:
    cl = ds['classifications']
    isic_code_to_name[ds['ISIC code']] = [c[1] for c in cl if c[0].startswith('ISIC')][0].split(':')[1]

with open('../data/lcia_case_studies/isic_code_to_name.p', 'wb') as o:
    pickle.dump(isic_code_to_name, o)

# match all full index-mr_key -> unified isic sector under the same mr_key
full_index_isic_sector = [isic_code_to_name[iot_sec_indexer_TO_isic_code[(tuple(mr_key_MRD[i[1]]['exiobase_sector_index']))]]
                          for i in full_index]
with open('../data/lcia_case_studies/full_index_isic_sector.p', 'wb') as o:
    pickle.dump(full_index_isic_sector, o)

# %%
full_index_referprod = [db.get(ref_ds_dict[tuple(i)]).as_dict()['reference product'] for i in full_index]
with open('../data/lcia_case_studies/full_index_referprod.p', 'wb') as o:
    pickle.dump(full_index_referprod, o)

# %%
full_index_unit = [db.get(ref_ds_dict[tuple(i)]).as_dict()['unit'] for i in full_index]
with open('../data/lcia_case_studies/full_index_unit.p', 'wb') as o:
    pickle.dump(full_index_unit, o)

# %%
full_index_ref_loc = [db.get(ref_ds_dict[tuple(i)]).as_dict()['location'] for i in full_index]
with open('../data/lcia_case_studies/full_index_ref_loc.p', 'wb') as o:
    pickle.dump(full_index_ref_loc, o)

# %% [markdown]
# ## 1. How to do LCA calculation?<a id='step1'></a> <br>
#  <a href='#back'>back</a>

# %% [markdown]
# We use the PyPardiso library developed by Haas (2016) to factorize the technosphere matrix once and then efficiently solve $(I-A)×x=y$ to get accumulated supply vectors $y$ for different demand vectors $x$.

# %%
solver = pp.PyPardisoSolver()
# %time solver.factorize(tec_mat)
# Out:
# CPU times: user 5h 1min 22s, sys: 32.3 s, total: 5h 1min 54s
# Wall time: 9min 31s

# %%
class RegionalizedLCA:
    '''
    Implement the regionalized version of ecoinvent to do a LCA study for a specific demand.
    
    '''
    def __init__(self, demand, method=None, solver=None):
        self.demand = demand
        self.method = method
        self.solver = solver
        self.technosphere_matrix = tec_mat
        self.biosphere_matrix = bio_mat
        self.full_index = full_index
        self.full_index_country = full_index_country
        self.full_index_isic_sector = full_index_isic_sector
        
        self.regions = sorted(list({i[0] for i in self.full_index_country}))  # for supply side aggregation
        self.sectors = sorted(list({i for i in self.full_index_isic_sector})) # 92 supply sectors
        self.region_id_mask = np.array([self.regions.index(r[0]) for r in self.full_index_country])
        self.sector_id_mask = np.array([self.sectors.index(r) for r in self.full_index_isic_sector])
        self.cfs = cfs_dict
        self.cfs_ei = cfs_ei_dict
        self.inv_ref_ds_dict = inv_ref_ds_dict
        
    def build_demand_array(self):
        demand_arr = np.zeros(self.technosphere_matrix.shape[0])
        for i, v in self.demand.items():
            demand_arr[self.full_index.index(i)] = v
        return demand_arr
    
    def lci(self):
        demand = self.build_demand_array()
        self.supply = solver.solve(self.technosphere_matrix, demand)
    
    def lcia(self):
        if not self.method:
            raise UserWarning('must choose method')
        self.inventory = self.biosphere_matrix *sp.diags(self.supply)
        cf_mat = self.cfs[self.method]
        if operator.eq(*cf_mat.shape):
            self.characterized_inventory = cf_mat*self.inventory #non-regionalized
        else:
            self.characterized_inventory = cf_mat.multiply(self.inventory) #regionalized
    
    def supply_country_aggregated_ChInventory(self):#aggregated by producer/supply co
        inventory_agg = np.array(self.characterized_inventory.sum(axis=0)).squeeze()
        country_agg = np.bincount(self.region_id_mask, weights=inventory_agg) 
        return country_agg
    
    def supply_sector_aggregated_ChInventory(self):#aggregated by producer/supply sectors
        inventory_agg = np.array(self.characterized_inventory.sum(axis=0)).squeeze()
        sector_agg = np.bincount(self.sector_id_mask, weights=inventory_agg) 
        return sector_agg
    
    def multi_inventory(self, region):
        region_indices = [i for i, ind in enumerate(self.full_index) if ind[0]==region]
        demand = np.zeros((self.technosphere_matrix.shape[0], len(region_indices)))
        for i, ri in enumerate(region_indices):
            demand[ri,i] = 1
        supply = self.solver.solve(self.technosphere_matrix, demand)
        return supply
    
    def switch_method(self, method):
        assert method in self.cfs, f'{method} not available'
        self.method = method
    
    def lcia_all(self):
        scores_dict = {}
        for method in self.cfs:
            self.switch_method(method)
            self.lcia()
            scores_dict[method] = self.characterized_inventory.sum()
        return scores_dict
    
    def ecoinvent_comparison(self, activity):
        ipcc = ('IPCC 2013', 'climate change', 'GWP 100a')
        eco_lca = bw.LCA({activity:1}, ipcc)
        eco_lca.lci()
        eco_lca.lcia()
        eco_res = {}
        eco_res['ipcc'] = eco_lca.score
        eco_lca.switch_method(recipe)
        inv = eco_lca.inventory
        for met in self.cfs_ei:
            ChaInv = self.cfs_ei[met]*inv 
            eco_res[met] = ChaInv.sum()
        res = {}
        name = 'ecoinvent' + ' '+ activity.as_dict()['location']
        res[name] = eco_res
        for region, ind in self.inv_ref_ds_dict[activity.key[1]].items():# for consumer side
            self.demand = {ind: 1}
            self.lci()
            scores = self.lcia_all()
            res[region] = scores #for specific ds, not all final location have it
        return res

# %%
pv_panel = db.search('photovoltaic panel production, single-Si wafer')
pv_panel
# Out:
# ['photovoltaic panel production, single-Si wafer' (square meter, RER, None),
#  'photovoltaic panel production, single-Si wafer' (square meter, RoW, None),
#  'photovoltaic laminate production, single-Si wafer' (square meter, RER, None),
#  'photovoltaic laminate production, single-Si wafer' (square meter, RoW, None)]

# %%
demand = {('CH', '00e4a6354bc9c5d21e73d00730e50071'): 1} #use a random demand to set up the calculation
lca = RegionalizedLCA(demand=demand, method='recipe')
# %time lca.lci()
# Out:
# CPU times: user 34.3 s, sys: 18.9 s, total: 53.1 s
# Wall time: 3.43 s

# %%
# %time panel_res = lca.ecoinvent_comparison(pv_panel[0])
res_df0 = pd.DataFrame(panel_res)
res_df0
# Out:
# CPU times: user 18min 31s, sys: 8min 39s, total: 27min 10s
# Wall time: 1min 55s
#               ecoinvent RER            LV            LU            IT  \
# ipcc           2.658813e+02  2.269065e+02  2.286902e+02  2.706202e+02
# recipe         2.948882e+01  2.673745e+01  2.574737e+01  2.882478e+01
# aware_glo_ei   3.316233e+02           NaN           NaN           NaN
# psl_glo_ei     5.607464e-14           NaN           NaN           NaN
# aware_glo               NaN  3.694287e+02  3.237023e+02  3.260930e+02
# aware_reg               NaN  1.072976e+02  1.417183e+02  2.039189e+02
# pslglo_glo              NaN  4.918720e-14  4.725640e-14  4.768185e-14
# pslglo_reg              NaN  3.232370e-14  4.387478e-14  5.313063e-14
#
#                         BG            SK            HR            HU  \
# ipcc          2.494517e+02  2.679614e+02  2.727938e+02  2.571892e+02
# recipe        2.772435e+01  2.886035e+01  2.913543e+01  2.807952e+01
# aware_glo_ei           NaN           NaN           NaN           NaN
# psl_glo_ei             NaN           NaN           NaN           NaN
# aware_glo     3.385094e+02  3.571568e+02  3.275486e+02  3.316758e+02
# aware_reg     1.579432e+02  1.698823e+02  1.997576e+02  1.748558e+02
# pslglo_glo    4.534008e-14  4.662867e-14  4.789191e-14  4.670822e-14
# pslglo_reg    4.600496e-14  4.643354e-14  4.876904e-14  4.520408e-14
#
#                         PT            LT  ...            SE            IE  \
# ipcc          2.082344e+02  2.632257e+02  ...  2.152739e+02  2.282412e+02
# recipe        2.400105e+01  2.859917e+01  ...  2.449027e+01  2.565908e+01
# aware_glo_ei           NaN           NaN  ...           NaN           NaN
# psl_glo_ei             NaN           NaN  ...           NaN           NaN
# aware_glo     3.221267e+02  3.403708e+02  ...  3.248444e+02  3.177724e+02
# aware_reg     2.236439e+02  1.702496e+02  ...  1.293514e+02  1.433921e+02
# pslglo_glo    4.525530e-14  4.866321e-14  ...  4.913776e-14  4.763652e-14
# pslglo_reg    5.672790e-14  4.112474e-14  ...  3.796681e-14  4.267220e-14
#
#                         EE            MT            BE            RO  \
# ipcc          2.645764e+02  2.323391e+02  2.580342e+02  2.516168e+02
# recipe        2.888844e+01  2.609658e+01  2.789693e+01  2.771259e+01
# aware_glo_ei           NaN           NaN           NaN           NaN
# psl_glo_ei             NaN           NaN           NaN           NaN
# aware_glo     3.370054e+02  3.304589e+02  3.221588e+02  3.411615e+02
# aware_reg     1.724986e+02  1.801400e+02  1.797612e+02  1.645351e+02
# pslglo_glo    5.049774e-14  4.705503e-14  4.756489e-14  4.498089e-14
# pslglo_reg    4.121555e-14  4.883466e-14  4.470011e-14  4.437434e-14
#
#                         SI            CH            ES            PL
# ipcc          2.591751e+02  2.514809e+02  2.663599e+02  2.855706e+02
# recipe        2.806346e+01  2.729533e+01  2.853111e+01  3.015378e+01
# aware_glo_ei           NaN           NaN           NaN           NaN
# psl_glo_ei             NaN           NaN           NaN           NaN
# aware_glo     3.335756e+02  3.306469e+02  3.239564e+02  3.360206e+02
# aware_reg     1.750412e+02  1.707359e+02  2.050575e+02  2.030394e+02
# pslglo_glo    4.636489e-14  4.607065e-14  4.736786e-14  4.832230e-14
# pslglo_reg    4.848409e-14  4.654336e-14  5.380303e-14  4.584496e-14
#
# [8 rows x 30 columns]

# %%
# %time panel_res = lca.ecoinvent_comparison(pv_panel[1])
res_df1 = pd.DataFrame(panel_res)
res_df1
# Out:
# CPU times: user 9min 52s, sys: 4min 32s, total: 14min 25s
# Wall time: 1min
#               ecoinvent RoW            MX            TW            BR  \
# ipcc           2.661995e+02  2.679074e+02  2.626166e+02  2.056790e+02
# recipe         2.961248e+01  2.913190e+01  2.906354e+01  2.328454e+01
# aware_glo_ei   3.309010e+02           NaN           NaN           NaN
# psl_glo_ei     5.624306e-14           NaN           NaN           NaN
# aware_glo               NaN  3.125063e+02  3.148781e+02  3.989338e+02
# aware_reg               NaN  2.349712e+02  1.769047e+02  1.413676e+02
# pslglo_glo              NaN  4.695549e-14  4.741230e-14  6.512821e-14
# pslglo_reg              NaN  5.078567e-14  5.320696e-14  8.035955e-14
#
#                         ID            TR            CY            US  \
# ipcc          2.811713e+02  2.891599e+02  2.492291e+02  2.799400e+02
# recipe        3.088007e+01  3.047905e+01  2.744092e+01  2.990731e+01
# aware_glo_ei           NaN           NaN           NaN           NaN
# psl_glo_ei             NaN           NaN           NaN           NaN
# aware_glo     3.107646e+02  3.197784e+02  3.271740e+02  3.135371e+02
# aware_reg     1.998073e+02  2.261766e+02  1.676916e+02  2.382245e+02
# pslglo_glo    4.647497e-14  4.807413e-14  4.715929e-14  4.916876e-14
# pslglo_reg    7.669978e-14  5.099719e-14  5.384386e-14  4.722756e-14
#
#                         AU            CA            IN            CN  \
# ipcc          3.043921e+02  2.698116e+02  3.154395e+02  3.287457e+02
# recipe        3.168960e+01  2.927487e+01  3.529297e+01  3.306070e+01
# aware_glo_ei           NaN           NaN           NaN           NaN
# psl_glo_ei             NaN           NaN           NaN           NaN
# aware_glo     3.103801e+02  3.232224e+02  3.051184e+02  3.073701e+02
# aware_reg     2.485038e+02  2.346554e+02  2.035880e+02  2.622977e+02
# pslglo_glo    4.789266e-14  5.639389e-14  5.403853e-14  5.804190e-14
# pslglo_reg    4.960528e-14  4.522551e-14  7.115346e-14  6.262754e-14
#
#                         RU            ZA            JP            KR
# ipcc          2.728308e+02  3.018575e+02  2.641358e+02  2.874654e+02
# recipe        2.936953e+01  3.422505e+01  2.874050e+01  3.040372e+01
# aware_glo_ei           NaN           NaN           NaN           NaN
# psl_glo_ei             NaN           NaN           NaN           NaN
# aware_glo     3.368515e+02  3.271559e+02  3.055188e+02  3.126932e+02
# aware_reg     1.955398e+02  2.026131e+02  6.131956e+01  1.850863e+02
# pslglo_glo    5.043155e-14  4.880265e-14  5.917728e-14  4.873760e-14
# pslglo_reg    4.154531e-14  7.303260e-14  1.210095e-13  5.691743e-14

# %%
res_df = pd.concat([res_df0, res_df1], axis=1)
res_df = res_df[sorted(res_df.columns.tolist())]
res_df.to_csv('../../Data/lcia_case_studies/PV_panel/PV_panel_ipcc_all_co.csv')

# %% [markdown]
# Let us visualize the impact results on a map or on a bar plot:

# %%
res_df =  pd.read_csv('../../Data/lcia_case_studies/PV_panel/PV_panel_ipcc_all_co.csv')
res_df = res_df.T
res_df.columns = res_df.iloc[0]
res_df = res_df.drop(res_df.index[0])
res_df['ipcc_relative'] = res_df['ipcc']/(res_df['ipcc']['ecoinvent RER']+res_df['ipcc']['ecoinvent RoW'])*2
res_df = res_df.drop(['ecoinvent RER','ecoinvent RoW']).reset_index().rename(columns = {'index':'Two_Letter_Country_Code'})
# res_df

# %%
country_code = pd.read_excel('../../Data/other_data/country-and-continent-codes-list-csv_csv_with_ME.xlsx',engine='openpyxl')
country_code = country_code[['Two_Letter_Country_Code','Three_Letter_Country_Code']]

# %%
res_df_3_code = res_df.merge(country_code, how='left', on='Two_Letter_Country_Code')
#there are double RU
res_df_3_code = res_df_3_code.drop(res_df_3_code.index[res_df_3_code['Two_Letter_Country_Code'] == 'RU'][0]).reset_index(drop=True)
res_df_3_code = res_df_3_code.rename(columns = {'Three_Letter_Country_Code':'iso_a3'})
res_df_3_code
# Out:
#    Two_Letter_Country_Code     ipcc   recipe aware_glo_ei psl_glo_ei  \
# 0                       AT  240.776  26.4462          NaN        NaN
# 1                       AU  304.392  31.6896          NaN        NaN
# 2                       BE  258.034  27.8969          NaN        NaN
# 3                       BG  249.452  27.7244          NaN        NaN
# 4                       BR  205.679  23.2845          NaN        NaN
# 5                       CA  269.812  29.2749          NaN        NaN
# 6                       CH  251.481  27.2953          NaN        NaN
# 7                       CN  328.746  33.0607          NaN        NaN
# 8                       CY  249.229  27.4409          NaN        NaN
# 9                       CZ   289.73  30.4313          NaN        NaN
# 10                      DE  275.075  29.1619          NaN        NaN
# 11                      DK  254.361  27.5347          NaN        NaN
# 12                      EE  264.576  28.8884          NaN        NaN
# 13                      ES   266.36  28.5311          NaN        NaN
# 14                      FI  267.711  28.5133          NaN        NaN
# 15                      FR  233.612  26.0046          NaN        NaN
# 16                      GB  258.365  27.9707          NaN        NaN
# 17                      GR  261.379  28.5948          NaN        NaN
# 18                      HR  272.794  29.1354          NaN        NaN
# 19                      HU  257.189  28.0795          NaN        NaN
# 20                      ID  281.171  30.8801          NaN        NaN
# 21                      IE  228.241  25.6591          NaN        NaN
# 22                      IN   315.44   35.293          NaN        NaN
# 23                      IT   270.62  28.8248          NaN        NaN
# 24                      JP  264.136  28.7405          NaN        NaN
# 25                      KR  287.465  30.4037          NaN        NaN
# 26                      LT  263.226  28.5992          NaN        NaN
# 27                      LU   228.69  25.7474          NaN        NaN
# 28                      LV  226.906  26.7374          NaN        NaN
# 29                      MT  232.339  26.0966          NaN        NaN
# 30                      MX  267.907  29.1319          NaN        NaN
# 31                      NL  234.806  26.3145          NaN        NaN
# 32                      NO  267.639  28.4967          NaN        NaN
# 33                      PL  285.571  30.1538          NaN        NaN
# 34                      PT  208.234   24.001          NaN        NaN
# 35                      RO  251.617  27.7126          NaN        NaN
# 36                      RU  272.831  29.3695          NaN        NaN
# 37                      SE  215.274  24.4903          NaN        NaN
# 38                      SI  259.175  28.0635          NaN        NaN
# 39                      SK  267.961  28.8604          NaN        NaN
# 40                      TR   289.16   30.479          NaN        NaN
# 41                      TW  262.617  29.0635          NaN        NaN
# 42                      US   279.94  29.9073          NaN        NaN
# 43                      ZA  301.857   34.225          NaN        NaN
#
#    aware_glo aware_reg   pslglo_glo   pslglo_reg ipcc_relative iso_a3
# 0    340.783   144.078   4.5411e-14  4.63987e-14      0.905034    AUT
# 1     310.38   248.504  4.78927e-14  4.96053e-14       1.14416    AUS
# 2    322.159   179.761  4.75649e-14  4.47001e-14      0.969906    BEL
# 3    338.509   157.943  4.53401e-14   4.6005e-14      0.937646    BGR
# 4    398.934   141.368  6.51282e-14  8.03595e-14      0.773112    BRA
# 5    323.222   234.655  5.63939e-14  4.52255e-14       1.01418    CAN
# 6    330.647   170.736  4.60707e-14  4.65434e-14      0.945273    CHE
# 7     307.37   262.298  5.80419e-14  6.26275e-14        1.2357    CHN
# 8    327.174   167.692  4.71593e-14  5.38439e-14      0.936809    CYP
# 9    343.917   198.652  4.76167e-14  4.55244e-14       1.08904    CZE
# 10   326.796   190.287  4.76279e-14  4.58642e-14       1.03396    DEU
# 11   330.377   173.295  4.87512e-14   4.2404e-14      0.956098    DNK
# 12   337.005   172.499  5.04977e-14  4.12155e-14      0.994497    EST
# 13   323.956   205.058  4.73679e-14   5.3803e-14        1.0012    ESP
# 14   323.495   193.317  4.87233e-14  4.32206e-14       1.00628    FIN
# 15    324.84   157.198   4.7925e-14  4.28253e-14      0.878107    FRA
# 16   320.308   180.728   4.9518e-14  4.39951e-14      0.971148    GBR
# 17   329.769   187.052  4.64162e-14  4.75388e-14      0.982477    GRC
# 18   327.549   199.758  4.78919e-14   4.8769e-14       1.02538    HRV
# 19   331.676   174.856  4.67082e-14  4.52041e-14       0.96673    HUN
# 20   310.765   199.807   4.6475e-14  7.66998e-14       1.05687    IDN
# 21   317.772   143.392  4.76365e-14  4.26722e-14      0.857919    IRL
# 22   305.118   203.588  5.40385e-14  7.11535e-14       1.18568    IND
# 23   326.093   203.919  4.76819e-14  5.31306e-14       1.01721    ITA
# 24   305.519   61.3196  5.91773e-14   1.2101e-13      0.992841    JPN
# 25   312.693   185.086  4.87376e-14  5.69174e-14       1.08053    KOR
# 26   340.371    170.25  4.86632e-14  4.11247e-14       0.98942    LTU
# 27   323.702   141.718  4.72564e-14  4.38748e-14      0.859607    LUX
# 28   369.429   107.298  4.91872e-14  3.23237e-14      0.852902    LVA
# 29   330.459    180.14   4.7055e-14  4.88347e-14      0.873323    MLT
# 30   312.506   234.971  4.69555e-14  5.07857e-14       1.00702    MEX
# 31   331.418    167.98  4.48785e-14  3.87979e-14      0.882595    NLD
# 32   333.332   199.588  4.90804e-14  4.42302e-14       1.00601    NOR
# 33   336.021   203.039  4.83223e-14   4.5845e-14       1.07341    POL
# 34   322.127   223.644  4.52553e-14  5.67279e-14      0.782717    PRT
# 35   341.162   164.535  4.49809e-14  4.43743e-14      0.945784    ROU
# 36   336.851    195.54  5.04316e-14  4.15453e-14       1.02552    RUS
# 37   324.844   129.351  4.91378e-14  3.79668e-14      0.809177    SWE
# 38   333.576   175.041  4.63649e-14  4.84841e-14      0.974194    SVN
# 39   357.157   169.882  4.66287e-14  4.64335e-14       1.00722    SVK
# 40   319.778   226.177  4.80741e-14  5.09972e-14        1.0869    TUR
# 41   314.878   176.905  4.74123e-14   5.3207e-14      0.987131    TWN
# 42   313.537   238.224  4.91688e-14  4.72276e-14       1.05225    USA
# 43   327.156   202.613  4.88026e-14  7.30326e-14       1.13463    ZAF

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
#the iso_a3 of following three countries are -99
world.at[world.index[world['name'] == 'Norway'], 'iso_a3'] = 'NOR'
world.at[world.index[world['name'] == 'France'], 'iso_a3'] = 'FRA'
world.at[world.index[world['name'] == 'Cyprus'], 'iso_a3'] = 'CYP'
world_merge = world.merge(res_df_3_code[['ipcc_relative','iso_a3']], how='left', on='iso_a3')

# fill na with 999 first, then later change it back to na. otherwise, affect plotting: cannot norm + discrete legend
world_merge['ipcc_relative'] = world_merge['ipcc_relative'].fillna(999)

# #drop ATA
world['ipcc_relative'] = world_merge['ipcc_relative']
world["ipcc_relative"] = world.ipcc_relative.apply(lambda x: x if x !=999 else np.nan)
world = world.drop(world.index[world['iso_a3'] == 'ATA']).reset_index(drop=True)
world
# Out:
#        pop_est      continent                      name iso_a3  gdp_md_est  \
# 0       920938        Oceania                      Fiji    FJI      8374.0
# 1     53950935         Africa                  Tanzania    TZA    150600.0
# 2       603253         Africa                 W. Sahara    ESH       906.5
# 3     35623680  North America                    Canada    CAN   1674000.0
# 4    326625791  North America  United States of America    USA  18560000.0
# ..         ...            ...                       ...    ...         ...
# 171    7111024         Europe                    Serbia    SRB    101800.0
# 172     642550         Europe                Montenegro    MNE     10610.0
# 173    1895250         Europe                    Kosovo    -99     18490.0
# 174    1218208  North America       Trinidad and Tobago    TTO     43570.0
# 175   13026129         Africa                  S. Sudan    SSD     20880.0
#
#                                               geometry  ipcc_relative
# 0    MULTIPOLYGON (((180.00000 -16.06713, 180.00000...            NaN
# 1    POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...            NaN
# 2    POLYGON ((-8.66559 27.65643, -8.66512 27.58948...            NaN
# 3    MULTIPOLYGON (((-122.84000 49.00000, -122.9742...       1.014175
# 4    MULTIPOLYGON (((-122.84000 49.00000, -120.0000...       1.052246
# ..                                                 ...            ...
# 171  POLYGON ((18.82982 45.90887, 18.82984 45.90888...            NaN
# 172  POLYGON ((20.07070 42.58863, 19.80161 42.50009...            NaN
# 173  POLYGON ((20.59025 41.85541, 20.52295 42.21787...            NaN
# 174  POLYGON ((-61.68000 10.76000, -61.10500 10.890...            NaN
# 175  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...            NaN
#
# [176 rows x 7 columns]

# %%
# Malta is not in gpd. 
set(res_df_3_code['iso_a3']) - set(world_merge['iso_a3'])-set(world_merge[world_merge.ipcc_relative.isna()]['iso_a3'])
# Out:
# {'MLT'}

# %%
# create a colormap and norm
colors = [(0, 0, 1), 'papayawhip', (1, 0, 0)]
cmap = mpl.colors.LinearSegmentedColormap.from_list('my_cmap', colors, N=256)
norm = mpl.colors.TwoSlopeNorm(vcenter=1, vmin=0.7, vmax=1.3) 

fig, ax1 = plt.subplots(1,1, figsize = (10,3)) 
# fig.suptitle('Regional impact based on regionalized ecoivent / RoW(/RER) impact based on ecoinvent',
#              fontsize = 'x-large', fontweight = 'bold')
    
world.plot(color = "lightgrey", ax = ax1)
world.dropna().plot(column = 'ipcc_relative',cmap = cmap,norm = norm,ax = ax1,legend = True)

fig.savefig('../plots/PV_panel/PV_panel_impact_pv_reg_comparison_map.png',dpi=300)

# %%
PV_panel_ipcc = res_df.loc['ipcc']
pv_regions = sorted(PV_panel_ipcc.keys())
pv_regions = [i for i in pv_regions if 'ecoinvent' not in i]

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 12), sharey=False)
for ax, df, name in zip(axes, (PV_panel_ipcc, PV_panel_recipe), ('ipcc', 'recipe')):
    df[pv_regions].plot(kind='barh', ax=ax, color='grey')
    if 'ecoinvent RER' in df.keys():
        ax.vlines(df['ecoinvent RER'], *ax.get_ylim(), color='red', label='ecoinvent RER')
    if 'ecoinvent RoW' in df.keys():
        ax.vlines(df['ecoinvent RoW'], *ax.get_ylim(), color='blue', label='ecoinvent RoW')
    ax.legend(loc='upper left')
    ax.set_title(name.upper())
    ax.invert_yaxis()
    ax.grid(axis='x', which='major', zorder=0)
fig.tight_layout()

fig.savefig('../plots/PV_panel/PV_panel_impact_pv_reg_comparison.png')

# %% [markdown]
# ## 2. How to get country or sector contributions to total impact?<a id='step2'></a> <br>
#  <a href='#back'>back</a>

# %%
ipcc = ('IPCC 2013', 'climate change', 'GWP 100a')

# %%
# define target regions (full_index)
PV_panel_regions1 = [lca.inv_ref_ds_dict[pv_panel[1].key[1]][r] for r in ('CN', 'JP')]
PV_panel_regions2 = [lca.inv_ref_ds_dict[pv_panel[0].key[1]]['DE']]
PV_panel_regions = PV_panel_regions1 + PV_panel_regions2
PV_panel_regions
# Out:
# [('CN', 'f541f67229f7b52b5386e96bc5a629c6'),
#  ('JP', 'f541f67229f7b52b5386e96bc5a629c6'),
#  ('DE', 'f541f67229f7b52b5386e96bc5a629c6')]

# %%
# %%time
sup_reg_dict = {}
sup_sec_dict = {}
for panel in PV_panel_regions:
    lca.demand = {panel: 1}
    lca.lci()
    res_reg = {}
    res_sec = {}
    with open('../../Data/lcia_case_studies/PV_panel/PV_panel_supply_'+panel[0]+'.p', 'wb') as o:
        pickle.dump(lca.supply, o)
    for method in ('ipcc'):
        lca.switch_method(method)
        lca.lcia()
        with open('../../Data/lcia_case_studies/PV_panel/PV_panel_characterized_inventory_'+method+'_'+panel[0]+'.p', 'wb') as o:
            pickle.dump(lca.characterized_inventory, o)
        res_reg[method] = pd.Series(lca.supply_country_aggregated_ChInventory(), index=lca.regions)
        res_sec[method] = pd.Series(lca.supply_sector_aggregated_ChInventory(), index=lca.sectors)
        
    sup_reg_dict[panel[0]] = pd.DataFrame(res_reg)
    sup_sec_dict[panel[0]] = pd.DataFrame(res_sec)
# Out:
# CPU times: user 1min 34s, sys: 1min 17s, total: 2min 52s
# Wall time: 25.8 s

# %%
for reg in ('CN', 'JP', 'DE'):
    df = sup_reg_dict[reg]
    df.to_csv('../../Data/lcia_case_studies/PV_panel/PV_panel_impact_supplychain_region_'+reg+'.csv')

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 10), sharey=False)
met = 'ipcc'

for ax, reg in zip(axes, ('CN', 'JP', 'DE')):
    df = sup_reg_dict[reg]
    sup_rel = df/df.sum(axis=0)
    data_fig = sup_rel[met].sort_values(ascending=False)[0:19]
    data_fig.plot(kind='barh', ax=ax, color='grey', label=met, zorder=3)
    ax.legend(loc='upper right',fontsize = 15)
    ax.grid(axis='x', which='major', zorder=0)
    ax.set_title(reg,fontsize = 15)
    ax.set_xlabel('ipcc score share', fontsize = 15)
    ax.set_ylabel('supplier', fontsize = 15)
    ax.tick_params(axis='both', labelsize=15)
    if met == 'ipcc':
        ax.set_xlim([0, 1])
    else:
        ax.set_xlim([0, 0.8])
fig.savefig('../plots/PV_panel/PV_panel_impact_supplychain_region_'+met+'.png')
fig.tight_layout()

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 8), sharey=False)
met = 'ipcc'

for ax, reg in zip(axes, ('CN', 'JP', 'DE')):
    df = sup_sec_dict[reg]
#     sup_rel = df/df.sum(axis=0)
    sup_rel = df
    data_fig = sup_rel[met].sort_values(ascending=False)[0:9]
    data_fig.plot(kind='barh', ax=ax, color='grey', label=met, zorder=3)
    ax.legend(loc='upper right', fontsize = 15)
    ax.grid(axis='x', which='major', zorder=0)
    ax.set_yticklabels([textwrap.fill(e, 15) for e in data_fig.keys()])
    ax.set_title(reg, fontsize = 15)
#     ax.set_xlabel('ipcc score share', fontsize = 15)
    ax.set_xlabel('ipcc score', fontsize = 15)
#     ax.set_ylabel('supplier', fontsize = 15)
    ax.tick_params(axis='x', labelsize=15)
    ax.tick_params(axis='y', labelsize=11)
    if met == 'ipcc':
#         ax.set_xlim([0, 0.8])#0.45 3
        ax.set_xlim([0, 250])
    else:
#         ax.set_xlim([0, 15]) #0.3 5
        ax.set_xlim([0, 0.4])
    
# fig.savefig('../plots/PV_panel/PV_panel_impact_supplychain_sector_'+met+'.png')
fig.savefig('../plots/PV_panel/PV_panel_absolute_impact_supplychain_sector_'+met+'.png')
fig.tight_layout()

# %% [markdown]
# ## 3. How to dig deeper and find out key processes and locations?<a id='step3'></a> <br>
#  <a href='#back'>back</a>

# %%
# check top 20 datasets as contributors
with pd.ExcelWriter("../../Data/lcia_case_studies/PV_panel/ipcc_top_ds_infor.xlsx") as writer: 
    ipcc_top = pd.DataFrame() 
    for co in ['CN', 'JP', 'DE']:
        with open('../../Data/lcia_case_studies/PV_panel/PV_panel_characterized_inventory_ipcc_'+co+'.p', 'rb') as i:
            CHinvent = pickle.load(i)
        CHinvent_sum = np.array(CHinvent.sum(axis=0)).squeeze()

        ind_max = CHinvent_sum.argsort()[-20:][::-1] #get index of sorted values /Descending
        score_max = [CHinvent_sum[i] for i in ind_max]
        full_ind_max = tuple(np.array(full_index)[ind_max])
        ds_name_max = [full_index_dsname[i] for i in ind_max]
        ds_loc_max = [full_index_loc[i] for i in ind_max]
        co_max = [full_index_country[i][0] for i in ind_max]
        refprod_max = [full_index_referprod[i] for i in ind_max]
        ds_unit_max = [full_index_unit[i] for i in ind_max]
        sec = [full_index_isic_sector[i] for i in ind_max]

        score_per_FU_max = [ipcc_per_FU[i] for i in ind_max]
        with open('../../Data/lcia_case_studies/PV_panel/PV_panel_supply_'+co+'.p', 'rb') as i:
            supply_ar = pickle.load(i)
        supply_l = [supply_ar[i] for i in ind_max]
        print(len(ind_max), len(supply_l))

        consume_co = [co for i in ind_max]

        df = pd.DataFrame({'consumer':consume_co,
                           'full index':full_index,
                           'supply country':full_index_country,
                           'dataset name':full_index_dsname,
                           'dataset location':full_index_loc,
                           'reference product':full_index_referprod,
                           'unit':full_index_unit,
                           'ipcc score per FU':ipcc_per_FU,
                           'ipcc score':CHinvent_sum,
                           'accumulated supply': tuple(supply_ar),
                           'ISIC classification': full_index_isic_sector}) 
        ipcc_top = pd.concat([ipcc_top,df])

    idx = pd.MultiIndex.from_product([['CN', 'JP', 'DE'],list(range(len(ind_max)))],names=['Country', 'Maximum'])
    ipcc_top = ipcc_top.set_index(idx)
    ipcc_top['accumulated supply calculated'] = ipcc_top['ipcc score']/ipcc_top['ipcc score per FU'] 
    ipcc_top.to_excel(writer)

# %%
# check 5 top co-isic combinations  as contributors
def get_top_co_isic(co):
    with open('../../Data/lcia_case_studies/PV_panel/PV_panel_characterized_inventory_ipcc_'+co+'.p', 'rb') as i:
        CHinvent = pickle.load(i)
    CHinvent_sum = np.array(CHinvent.sum(axis=0)).squeeze()
    consume_co = [co for i in CHinvent_sum]
    supply_co = [i[0] for i in full_index_country]
    df_all = pd.DataFrame({'consumer':consume_co,
                       'full index':full_index,
                       'supply country':supply_co,
                       'dataset name':full_index_dsname,
                       'dataset location':full_index_ref_loc,
                       'reference product':full_index_referprod,
                       'unit':full_index_unit,
                       'ipcc score':CHinvent_sum,
                       'ISIC classification': full_index_isic_sector}) 
    
    df_co_isic = df_all.groupby(['supply country','ISIC classification'])['ipcc score'].sum().reset_index()
    df_co_isic = df_co_isic.sort_values(by=['ipcc score'], ascending=False).reset_index(drop=True)
    df_top = df_co_isic[:5]
    df_top.loc[len(df_top.index)] = ['Others', '', df_all['ipcc score'].sum()-df_top['ipcc score'].sum()] 
    return df_all,df_top

# %%
df_all_CN,df_top_CN = get_top_co_isic('CN')
df_all_DE,df_top_DE = get_top_co_isic('DE')
df_all_JP,df_top_JP = get_top_co_isic('JP')

# %% [markdown]
# In the top 5 combinations of country-sector, we can observe that 'Electric power generation, transmission and distribution' (Hereafter simply power sector) in certain countries keep dominating the GWP:
# - For Chinese PV panel production, Chinese power sector contributes most.
# - For German PV panel production, Chinese and German power sectors contribute most.
# - For Japanese PV panel production, Japanese and Chinese power sectors contribute most.
#
# Next, we disaggregate these regional power sectors into regional electricity production processes. The main electricity sources in each country can be gained from market composition data from ecoinvent.  |

# %%
elec_type_name = {'Electricity production, lignite':('electricity production, lignite','heat and power co-generation, lignite'),
                  'Electricity production, coal':('electricity production, coal','electricity production, hard coal','heat and power co-generation, hard coal'),
                  'Electricity production, natural gas':('electricity production, natural gas','heat and power co-generation, natural gas')
                  }
# 'Electricity production, hydro':'electricity production, hydro' is main source but not considered due to low GWP

def disaggre_elec_of_co(df_all, df_top, elec_sup_co):
    df_elec = df_all[(df_all['supply country']==elec_sup_co)&(df_all['ISIC classification']=='Electric power generation, transmission and distribution')]
    
    df_elec_plot = pd.DataFrame(columns=['supply country','ISIC classification','ipcc score']) 
    for k in elec_type_name.keys():
        if elec_sup_co!='DE' and k=='Electricity production, lignite': # some unimportant regional processes we want to skip
            continue
        if elec_sup_co=='DE' and k=='Electricity production, natural gas':
            continue
        elec_k = df_elec[(df_elec['unit']=='kilowatt hour')&[i.startswith(elec_type_name[k]) for i in df_elec['dataset name']]]
        df_elec_plot.loc[len(df_elec_plot.index)] = [elec_sup_co, k, elec_k['ipcc score'].sum()]
    df_elec_plot.loc[len(df_elec_plot.index)] = [elec_sup_co, 'Electricity activities, others', 
                                                 df_elec['ipcc score'].sum()-df_elec_plot['ipcc score'].sum()]   
    
    # summarize key processes in regional power sector + other top 5 regional sectors
    bound = df_top.index[(df_top['supply country']==elec_sup_co)&(df_top['ISIC classification']=='Electric power generation, transmission and distribution')].tolist()[0]
    df_plot1 = df_top.iloc[:bound]
    df_plot2 = df_top.iloc[(bound+1):]
    df_after_disaggre = pd.concat([df_plot1,df_elec_plot,df_plot2]) 
    df_after_disaggre = df_after_disaggre.reset_index(drop=True)
    return df_after_disaggre

# %%
df_plot_CN = disaggre_elec_of_co(df_all_CN, df_top_CN,'CN').rename(columns={"ipcc score": "China"}).set_index(['supply country','ISIC classification'])

df_plot_DE = disaggre_elec_of_co(df_all_DE, df_top_DE,'DE')
df_plot_DE = disaggre_elec_of_co(df_all_DE, df_plot_DE,'CN').rename(columns={"ipcc score": "Germany"}).set_index(['supply country','ISIC classification'])

df_plot_JP = disaggre_elec_of_co(df_all_JP, df_top_JP,'JP')
df_plot_JP = disaggre_elec_of_co(df_all_JP, df_plot_JP,'CN').rename(columns={"ipcc score": "Japan"}).set_index(['supply country','ISIC classification'])
# Out:
# /home/sipeng2/miniconda3/envs/reg_eco/lib/python3.6/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df_plot = pd.concat([df_plot_JP, df_plot_DE, df_plot_CN], axis=1)
df_plot = df_plot.reindex(["CN", "JP", "DE", 'US','IN', 'AU','Others'], axis=0, level=0)
df_plot.to_csv('../../Data/lcia_case_studies/PV_panel/PV_panel_ipcc_CN_JP_DE.csv')

# %% [markdown]
# ## 4. How to trace the country-level consumption mixes of products based on IOT?<a id='step4'></a> <br>
#
# Now, we already got LCA results of the target activity and need to trace the supply chain to explain the results. For example, we need to know why Chinese power production plays a key role in GWP caused by German PV panel production.  <br>
# In this study, for a technosphere input into a dataset, the shares of its origins are mainly determined by the country-level consumption mixes from ecoinvent, which further affects the impact contributions of various regional processes. Thus, we need to get the country-level consumption mixes of relevant products (such as PV components and silicon) from EXIOBASE. <br>
# This section uses an example (how to get the German consumption mix of PV cells for PV panel production) to indicate the procedure.
#
#  <a href='#back'>back</a>

# %%
# Step 1: get the exiobase sector of consumer
cons = db.search('photovoltaic panel production, single wafer')
print(cons[0].as_dict()['classifications'])
# Out:
# [('ISIC rev.4 ecoinvent',
#   '0111:Growing of cereals (except rice), leguminous crops and oil seeds'),
#  ('CPC', '01122: Maize (corn), other')]

# %%
def get_exio_sec_from_isic_code(isic_code):
    possible_full_isic_codes = [code for code in isic_TO_exio_name.keys() if code.startswith(isic_code)]
    exio_sec_name = list({sector for sector in itertools.chain.from_iterable([isic_TO_exio_name[c] for c in possible_full_isic_codes])})
    exio_sec_name
    
isic_cons = '2610'
exio_sec_name_cons = get_exio_sec_from_isic_code(isic_cons)

# %%
# Step 2: get the exiobase sector of producer
prod = db.search('photovoltaic cell production, single-Si wafer')
print(prod[0].as_dict()['classifications'])
# Out:
# ['Cultivation of wheat',
#  'Cultivation of cereal grains nec',
#  'Cultivation of oil seeds']

# %%
prod_cons = '2610'
exio_sec_name_prod = get_exio_sec_from_isic_code(prod_cons)
exio_sec_name_prod

# %%
# Step 3: get the import ratios
input_series = pd.DataFrame(index = iot.index)
for j in ['CH']:
    for i in exio_sec_name_cons:
        input_series = pd.concat([input_series,iot[j,i]], axis=1)
input_series = input_series.drop(labels=['WA','WE','WF','WL','WM'], level=0)
# input_series
input_certain = input_series.loc[(slice(None),exio_sec_name_prod),:]
input_certain_sum = input_certain.sum().sum()
import_ratio = {}
for co in iot_co:
    import_ratio[co]=input_certain.loc[co].sum().sum()/input_certain_sum
main_supplier = sorted(import_ratio.items(), key=lambda x: x[1], reverse=True)[:10]
main_supplier
# Out:
# [('TR', 0.614458065898913),
#  ('RU', 0.30448544902469227),
#  ('IN', 0.02673738153272467),
#  ('FI', 0.014918140485070553),
#  ('CH', 0.01347369827661044),
#  ('BR', 0.010133239030693686),
#  ('SE', 0.0035246457130880516),
#  ('DE', 0.003267024315592948),
#  ('FR', 0.003045505785594743),
#  ('AT', 0.0012772479654927704)]

# %%
iot_reg_co = {multi_index[0] for multi_index in iot.index}
iot_others = iot_reg_co.copy()
iot_others.difference_update(['CN','DE','JP','WA','WE','WF','WL','WM'])

# %%
input_certain
# Out:
#                                                            (NL, Manufacture of office machinery and computers (30))  \
# region sector
# AT     Manufacture of office machinery and computers (30)                                           0.000255
# AU     Manufacture of office machinery and computers (30)                                           0.000203
# BE     Manufacture of office machinery and computers (30)                                           0.001868
# BG     Manufacture of office machinery and computers (30)                                           0.000066
# BR     Manufacture of office machinery and computers (30)                                           0.000303
# CA     Manufacture of office machinery and computers (30)                                           0.000508
# CH     Manufacture of office machinery and computers (30)                                           0.002166
# CN     Manufacture of office machinery and computers (30)                                           0.041759
# CY     Manufacture of office machinery and computers (30)                                           0.000000
# CZ     Manufacture of office machinery and computers (30)                                           0.002727
# DE     Manufacture of office machinery and computers (30)                                           0.008398
# DK     Manufacture of office machinery and computers (30)                                           0.000579
# EE     Manufacture of office machinery and computers (30)                                           0.000033
# ES     Manufacture of office machinery and computers (30)                                           0.000389
# FI     Manufacture of office machinery and computers (30)                                           0.000066
# FR     Manufacture of office machinery and computers (30)                                           0.000145
# GB     Manufacture of office machinery and computers (30)                                           0.083605
# GR     Manufacture of office machinery and computers (30)                                           0.000003
# HR     Manufacture of office machinery and computers (30)                                           0.000005
# HU     Manufacture of office machinery and computers (30)                                           0.001405
# ID     Manufacture of office machinery and computers (30)                                           0.000161
# IE     Manufacture of office machinery and computers (30)                                           0.039850
# IN     Manufacture of office machinery and computers (30)                                           0.000200
# IT     Manufacture of office machinery and computers (30)                                           0.004591
# JP     Manufacture of office machinery and computers (30)                                           0.000000
# KR     Manufacture of office machinery and computers (30)                                           0.000249
# LT     Manufacture of office machinery and computers (30)                                           0.000114
# LU     Manufacture of office machinery and computers (30)                                           0.000048
# LV     Manufacture of office machinery and computers (30)                                           0.000025
# MT     Manufacture of office machinery and computers (30)                                           0.000010
# MX     Manufacture of office machinery and computers (30)                                           0.001257
# NL     Manufacture of office machinery and computers (30)                                          15.078102
# NO     Manufacture of office machinery and computers (30)                                           0.000002
# PL     Manufacture of office machinery and computers (30)                                           0.000293
# PT     Manufacture of office machinery and computers (30)                                           0.000098
# RO     Manufacture of office machinery and computers (30)                                           0.000198
# RU     Manufacture of office machinery and computers (30)                                           0.000029
# SE     Manufacture of office machinery and computers (30)                                           0.003011
# SI     Manufacture of office machinery and computers (30)                                           0.000118
# SK     Manufacture of office machinery and computers (30)                                           0.002339
# TR     Manufacture of office machinery and computers (30)                                           0.000061
# TW     Manufacture of office machinery and computers (30)                                           0.000000
# US     Manufacture of office machinery and computers (30)                                           0.010679
# ZA     Manufacture of office machinery and computers (30)                                           0.000130
#
#                                                            (HR, Manufacture of office machinery and computers (30))  \
# region sector
# AT     Manufacture of office machinery and computers (30)                                       5.436416e-04
# AU     Manufacture of office machinery and computers (30)                                       5.770115e-05
# BE     Manufacture of office machinery and computers (30)                                       2.452447e-04
# BG     Manufacture of office machinery and computers (30)                                       1.404667e-04
# BR     Manufacture of office machinery and computers (30)                                       2.924810e-10
# CA     Manufacture of office machinery and computers (30)                                       1.522189e-04
# CH     Manufacture of office machinery and computers (30)                                       1.300989e-03
# CN     Manufacture of office machinery and computers (30)                                       7.316004e-02
# CY     Manufacture of office machinery and computers (30)                                       0.000000e+00
# CZ     Manufacture of office machinery and computers (30)                                       1.359381e-02
# DE     Manufacture of office machinery and computers (30)                                       2.163022e-02
# DK     Manufacture of office machinery and computers (30)                                       1.162218e-06
# EE     Manufacture of office machinery and computers (30)                                       1.355542e-05
# ES     Manufacture of office machinery and computers (30)                                       1.715907e-04
# FI     Manufacture of office machinery and computers (30)                                       1.636291e-04
# FR     Manufacture of office machinery and computers (30)                                       5.866961e-03
# GB     Manufacture of office machinery and computers (30)                                       6.932245e-04
# GR     Manufacture of office machinery and computers (30)                                       3.007143e-06
# HR     Manufacture of office machinery and computers (30)                                       3.563657e-03
# HU     Manufacture of office machinery and computers (30)                                       1.046507e-02
# ID     Manufacture of office machinery and computers (30)                                       3.339189e-04
# IE     Manufacture of office machinery and computers (30)                                       1.320670e-02
# IN     Manufacture of office machinery and computers (30)                                       2.214128e-04
# IT     Manufacture of office machinery and computers (30)                                       5.742398e-04
# JP     Manufacture of office machinery and computers (30)                                       1.978193e-03
# KR     Manufacture of office machinery and computers (30)                                       3.566352e-03
# LT     Manufacture of office machinery and computers (30)                                       2.166526e-05
# LU     Manufacture of office machinery and computers (30)                                       7.160796e-07
# LV     Manufacture of office machinery and computers (30)                                       7.887617e-05
# MT     Manufacture of office machinery and computers (30)                                       2.041780e-07
# MX     Manufacture of office machinery and computers (30)                                       2.156615e-03
# NL     Manufacture of office machinery and computers (30)                                       6.097908e-04
# NO     Manufacture of office machinery and computers (30)                                       5.714647e-05
# PL     Manufacture of office machinery and computers (30)                                       5.620985e-05
# PT     Manufacture of office machinery and computers (30)                                       9.780686e-06
# RO     Manufacture of office machinery and computers (30)                                       3.859211e-04
# RU     Manufacture of office machinery and computers (30)                                       1.245301e-05
# SE     Manufacture of office machinery and computers (30)                                       3.616676e-04
# SI     Manufacture of office machinery and computers (30)                                       1.282214e-03
# SK     Manufacture of office machinery and computers (30)                                       3.956479e-04
# TR     Manufacture of office machinery and computers (30)                                       2.695208e-05
# TW     Manufacture of office machinery and computers (30)                                       2.137727e-03
# US     Manufacture of office machinery and computers (30)                                       1.126210e-02
# ZA     Manufacture of office machinery and computers (30)                                       8.658617e-05
#
#                                                            (DK, Manufacture of office machinery and computers (30))  \
# region sector
# AT     Manufacture of office machinery and computers (30)                                       2.040726e-03
# AU     Manufacture of office machinery and computers (30)                                       1.198195e-02
# BE     Manufacture of office machinery and computers (30)                                       2.042969e-02
# BG     Manufacture of office machinery and computers (30)                                       1.987543e-03
# BR     Manufacture of office machinery and computers (30)                                       5.219060e-04
# CA     Manufacture of office machinery and computers (30)                                       8.022752e-03
# CH     Manufacture of office machinery and computers (30)                                       5.862006e-02
# CN     Manufacture of office machinery and computers (30)                                       1.354799e+00
# CY     Manufacture of office machinery and computers (30)                                       0.000000e+00
# CZ     Manufacture of office machinery and computers (30)                                       4.138549e-01
# DE     Manufacture of office machinery and computers (30)                                       1.199370e+00
# DK     Manufacture of office machinery and computers (30)                                       1.851281e-01
# EE     Manufacture of office machinery and computers (30)                                       1.103075e-03
# ES     Manufacture of office machinery and computers (30)                                       6.949824e-03
# FI     Manufacture of office machinery and computers (30)                                       5.135023e-03
# FR     Manufacture of office machinery and computers (30)                                       1.060620e-01
# GB     Manufacture of office machinery and computers (30)                                       1.304889e-01
# GR     Manufacture of office machinery and computers (30)                                       1.434043e-04
# HR     Manufacture of office machinery and computers (30)                                       1.260905e-05
# HU     Manufacture of office machinery and computers (30)                                       1.703604e-01
# ID     Manufacture of office machinery and computers (30)                                       8.150684e-04
# IE     Manufacture of office machinery and computers (30)                                       9.007478e-01
# IN     Manufacture of office machinery and computers (30)                                       3.888929e-03
# IT     Manufacture of office machinery and computers (30)                                       1.830474e-02
# JP     Manufacture of office machinery and computers (30)                                       1.792035e-02
# KR     Manufacture of office machinery and computers (30)                                       2.418623e-02
# LT     Manufacture of office machinery and computers (30)                                       6.499703e-04
# LU     Manufacture of office machinery and computers (30)                                       1.091541e-05
# LV     Manufacture of office machinery and computers (30)                                       3.329582e-03
# MT     Manufacture of office machinery and computers (30)                                       2.704891e-04
# MX     Manufacture of office machinery and computers (30)                                       3.642470e-02
# NL     Manufacture of office machinery and computers (30)                                       5.851269e-02
# NO     Manufacture of office machinery and computers (30)                                       3.998520e-04
# PL     Manufacture of office machinery and computers (30)                                       9.386807e-03
# PT     Manufacture of office machinery and computers (30)                                       1.784953e-03
# RO     Manufacture of office machinery and computers (30)                                       7.511940e-03
# RU     Manufacture of office machinery and computers (30)                                       5.052575e-05
# SE     Manufacture of office machinery and computers (30)                                       2.360938e-01
# SI     Manufacture of office machinery and computers (30)                                       1.538958e-03
# SK     Manufacture of office machinery and computers (30)                                       8.504915e-03
# TR     Manufacture of office machinery and computers (30)                                       1.893241e-04
# TW     Manufacture of office machinery and computers (30)                                       1.666741e-08
# US     Manufacture of office machinery and computers (30)                                       2.407533e-01
# ZA     Manufacture of office machinery and computers (30)                                       3.623255e-04
#
#                                                            (FR, Manufacture of office machinery and computers (30))  \
# region sector
# AT     Manufacture of office machinery and computers (30)                                           0.000942
# AU     Manufacture of office machinery and computers (30)                                           0.000071
# BE     Manufacture of office machinery and computers (30)                                           0.016558
# BG     Manufacture of office machinery and computers (30)                                           0.000537
# BR     Manufacture of office machinery and computers (30)                                           0.000088
# CA     Manufacture of office machinery and computers (30)                                           0.003419
# CH     Manufacture of office machinery and computers (30)                                           0.001386
# CN     Manufacture of office machinery and computers (30)                                           0.018872
# CY     Manufacture of office machinery and computers (30)                                           0.000000
# CZ     Manufacture of office machinery and computers (30)                                           0.008115
# DE     Manufacture of office machinery and computers (30)                                           0.020134
# DK     Manufacture of office machinery and computers (30)                                           0.000977
# EE     Manufacture of office machinery and computers (30)                                           0.000023
# ES     Manufacture of office machinery and computers (30)                                           0.000650
# FI     Manufacture of office machinery and computers (30)                                           0.000359
# FR     Manufacture of office machinery and computers (30)                                           0.000000
# GB     Manufacture of office machinery and computers (30)                                           0.215509
# GR     Manufacture of office machinery and computers (30)                                           0.000005
# HR     Manufacture of office machinery and computers (30)                                           0.000012
# HU     Manufacture of office machinery and computers (30)                                           0.014128
# ID     Manufacture of office machinery and computers (30)                                           0.000055
# IE     Manufacture of office machinery and computers (30)                                           0.025762
# IN     Manufacture of office machinery and computers (30)                                           0.000073
# IT     Manufacture of office machinery and computers (30)                                           0.041618
# JP     Manufacture of office machinery and computers (30)                                           0.000557
# KR     Manufacture of office machinery and computers (30)                                           0.000422
# LT     Manufacture of office machinery and computers (30)                                           0.000055
# LU     Manufacture of office machinery and computers (30)                                           0.000031
# LV     Manufacture of office machinery and computers (30)                                           0.000006
# MT     Manufacture of office machinery and computers (30)                                           0.000001
# MX     Manufacture of office machinery and computers (30)                                           0.002091
# NL     Manufacture of office machinery and computers (30)                                           0.003035
# NO     Manufacture of office machinery and computers (30)                                           0.000006
# PL     Manufacture of office machinery and computers (30)                                           0.001520
# PT     Manufacture of office machinery and computers (30)                                           0.000030
# RO     Manufacture of office machinery and computers (30)                                           0.000074
# RU     Manufacture of office machinery and computers (30)                                           0.000007
# SE     Manufacture of office machinery and computers (30)                                           0.001861
# SI     Manufacture of office machinery and computers (30)                                           0.000381
# SK     Manufacture of office machinery and computers (30)                                           0.010796
# TR     Manufacture of office machinery and computers (30)                                           0.001958
# TW     Manufacture of office machinery and computers (30)                                           0.000787
# US     Manufacture of office machinery and computers (30)                                           0.018174
# ZA     Manufacture of office machinery and computers (30)                                           0.001204
#
#                                                            (SK, Manufacture of office machinery and computers (30))  \
# region sector
# AT     Manufacture of office machinery and computers (30)                                           1.869189
# AU     Manufacture of office machinery and computers (30)                                           0.086503
# BE     Manufacture of office machinery and computers (30)                                           0.194787
# BG     Manufacture of office machinery and computers (30)                                           0.393035
# BR     Manufacture of office machinery and computers (30)                                           0.000141
# CA     Manufacture of office machinery and computers (30)                                           3.154298
# CH     Manufacture of office machinery and computers (30)                                           0.441064
# CN     Manufacture of office machinery and computers (30)                                          51.710350
# CY     Manufacture of office machinery and computers (30)                                           0.000000
# CZ     Manufacture of office machinery and computers (30)                                          40.457936
# DE     Manufacture of office machinery and computers (30)                                          16.146640
# DK     Manufacture of office machinery and computers (30)                                           0.003111
# EE     Manufacture of office machinery and computers (30)                                           0.000374
# ES     Manufacture of office machinery and computers (30)                                           0.262812
# FI     Manufacture of office machinery and computers (30)                                           0.029294
# FR     Manufacture of office machinery and computers (30)                                           2.582049
# GB     Manufacture of office machinery and computers (30)                                           0.380056
# GR     Manufacture of office machinery and computers (30)                                           0.025895
# HR     Manufacture of office machinery and computers (30)                                           0.000883
# HU     Manufacture of office machinery and computers (30)                                           5.044153
# ID     Manufacture of office machinery and computers (30)                                           0.176095
# IE     Manufacture of office machinery and computers (30)                                           1.935239
# IN     Manufacture of office machinery and computers (30)                                           0.286645
# IT     Manufacture of office machinery and computers (30)                                           6.150988
# JP     Manufacture of office machinery and computers (30)                                           2.298704
# KR     Manufacture of office machinery and computers (30)                                           3.496895
# LT     Manufacture of office machinery and computers (30)                                           0.003140
# LU     Manufacture of office machinery and computers (30)                                           0.000029
# LV     Manufacture of office machinery and computers (30)                                           0.112419
# MT     Manufacture of office machinery and computers (30)                                           0.000015
# MX     Manufacture of office machinery and computers (30)                                           0.193671
# NL     Manufacture of office machinery and computers (30)                                           1.487814
# NO     Manufacture of office machinery and computers (30)                                           0.012109
# PL     Manufacture of office machinery and computers (30)                                           2.326830
# PT     Manufacture of office machinery and computers (30)                                           0.009511
# RO     Manufacture of office machinery and computers (30)                                           3.686689
# RU     Manufacture of office machinery and computers (30)                                           0.004192
# SE     Manufacture of office machinery and computers (30)                                           0.092415
# SI     Manufacture of office machinery and computers (30)                                           0.187352
# SK     Manufacture of office machinery and computers (30)                                          74.082165
# TR     Manufacture of office machinery and computers (30)                                           0.005784
# TW     Manufacture of office machinery and computers (30)                                           1.636932
# US     Manufacture of office machinery and computers (30)                                           2.931455
# ZA     Manufacture of office machinery and computers (30)                                           0.000068
#
#                                                            (ES, Manufacture of office machinery and computers (30))  \
# region sector
# AT     Manufacture of office machinery and computers (30)                                           0.161083
# AU     Manufacture of office machinery and computers (30)                                           0.039333
# BE     Manufacture of office machinery and computers (30)                                           0.689036
# BG     Manufacture of office machinery and computers (30)                                           0.098930
# BR     Manufacture of office machinery and computers (30)                                           0.029188
# CA     Manufacture of office machinery and computers (30)                                           0.182605
# CH     Manufacture of office machinery and computers (30)                                           1.847702
# CN     Manufacture of office machinery and computers (30)                                          58.865529
# CY     Manufacture of office machinery and computers (30)                                           0.000000
# CZ     Manufacture of office machinery and computers (30)                                          11.178524
# DE     Manufacture of office machinery and computers (30)                                          26.785289
# DK     Manufacture of office machinery and computers (30)                                           0.025716
# EE     Manufacture of office machinery and computers (30)                                           0.006390
# ES     Manufacture of office machinery and computers (30)                                           0.089179
# FI     Manufacture of office machinery and computers (30)                                           0.140147
# FR     Manufacture of office machinery and computers (30)                                           6.966614
# GB     Manufacture of office machinery and computers (30)                                           2.069684
# GR     Manufacture of office machinery and computers (30)                                           0.001732
# HR     Manufacture of office machinery and computers (30)                                           0.000213
# HU     Manufacture of office machinery and computers (30)                                           2.897626
# ID     Manufacture of office machinery and computers (30)                                           0.139659
# IE     Manufacture of office machinery and computers (30)                                          15.197211
# IN     Manufacture of office machinery and computers (30)                                           0.058178
# IT     Manufacture of office machinery and computers (30)                                          14.757193
# JP     Manufacture of office machinery and computers (30)                                           1.017387
# KR     Manufacture of office machinery and computers (30)                                           1.409794
# LT     Manufacture of office machinery and computers (30)                                           0.002041
# LU     Manufacture of office machinery and computers (30)                                           0.000072
# LV     Manufacture of office machinery and computers (30)                                           0.045292
# MT     Manufacture of office machinery and computers (30)                                           0.000232
# MX     Manufacture of office machinery and computers (30)                                           1.081386
# NL     Manufacture of office machinery and computers (30)                                           2.838823
# NO     Manufacture of office machinery and computers (30)                                           0.020534
# PL     Manufacture of office machinery and computers (30)                                           0.983890
# PT     Manufacture of office machinery and computers (30)                                           0.814455
# RO     Manufacture of office machinery and computers (30)                                           0.064015
# RU     Manufacture of office machinery and computers (30)                                           0.012803
# SE     Manufacture of office machinery and computers (30)                                           0.201702
# SI     Manufacture of office machinery and computers (30)                                           0.007850
# SK     Manufacture of office machinery and computers (30)                                           0.114078
# TR     Manufacture of office machinery and computers (30)                                           0.012273
# TW     Manufacture of office machinery and computers (30)                                           2.221174
# US     Manufacture of office machinery and computers (30)                                           7.845475
# ZA     Manufacture of office machinery and computers (30)                                           0.015546
#
#                                                            (NO, Manufacture of office machinery and computers (30))  \
# region sector
# AT     Manufacture of office machinery and computers (30)                                           0.084265
# AU     Manufacture of office machinery and computers (30)                                           0.032062
# BE     Manufacture of office machinery and computers (30)                                           0.176563
# BG     Manufacture of office machinery and computers (30)                                           0.004701
# BR     Manufacture of office machinery and computers (30)                                           0.003127
# CA     Manufacture of office machinery and computers (30)                                           0.089160
# CH     Manufacture of office machinery and computers (30)                                           0.189680
# CN     Manufacture of office machinery and computers (30)                                          20.376670
# CY     Manufacture of office machinery and computers (30)                                           0.000000
# CZ     Manufacture of office machinery and computers (30)                                           3.205596
# DE     Manufacture of office machinery and computers (30)                                           2.516833
# DK     Manufacture of office machinery and computers (30)                                           0.478318
# EE     Manufacture of office machinery and computers (30)                                           0.031558
# ES     Manufacture of office machinery and computers (30)                                           0.024014
# FI     Manufacture of office machinery and computers (30)                                           0.154970
# FR     Manufacture of office machinery and computers (30)                                           0.682916
# GB     Manufacture of office machinery and computers (30)                                           0.404545
# GR     Manufacture of office machinery and computers (30)                                           0.001582
# HR     Manufacture of office machinery and computers (30)                                           0.000044
# HU     Manufacture of office machinery and computers (30)                                           0.442236
# ID     Manufacture of office machinery and computers (30)                                           0.079531
# IE     Manufacture of office machinery and computers (30)                                           2.586195
# IN     Manufacture of office machinery and computers (30)                                           0.007886
# IT     Manufacture of office machinery and computers (30)                                           0.192260
# JP     Manufacture of office machinery and computers (30)                                           0.418446
# KR     Manufacture of office machinery and computers (30)                                           0.324760
# LT     Manufacture of office machinery and computers (30)                                           0.001571
# LU     Manufacture of office machinery and computers (30)                                           0.006172
# LV     Manufacture of office machinery and computers (30)                                           0.014792
# MT     Manufacture of office machinery and computers (30)                                           0.000327
# MX     Manufacture of office machinery and computers (30)                                           0.339712
# NL     Manufacture of office machinery and computers (30)                                           0.384201
# NO     Manufacture of office machinery and computers (30)                                           0.207982
# PL     Manufacture of office machinery and computers (30)                                           0.505352
# PT     Manufacture of office machinery and computers (30)                                           0.000427
# RO     Manufacture of office machinery and computers (30)                                           0.103104
# RU     Manufacture of office machinery and computers (30)                                           0.001030
# SE     Manufacture of office machinery and computers (30)                                           3.852477
# SI     Manufacture of office machinery and computers (30)                                           0.003294
# SK     Manufacture of office machinery and computers (30)                                           0.019814
# TR     Manufacture of office machinery and computers (30)                                           0.003010
# TW     Manufacture of office machinery and computers (30)                                           1.547941
# US     Manufacture of office machinery and computers (30)                                           3.234531
# ZA     Manufacture of office machinery and computers (30)                                           0.002589
#
#                                                            (CY, Manufacture of office machinery and computers (30))  \
# region sector
# AT     Manufacture of office machinery and computers (30)                                                  0
# AU     Manufacture of office machinery and computers (30)                                                  0
# BE     Manufacture of office machinery and computers (30)                                                  0
# BG     Manufacture of office machinery and computers (30)                                                  0
# BR     Manufacture of office machinery and computers (30)                                                  0
# CA     Manufacture of office machinery and computers (30)                                                  0
# CH     Manufacture of office machinery and computers (30)                                                  0
# CN     Manufacture of office machinery and computers (30)                                                  0
# CY     Manufacture of office machinery and computers (30)                                                  0
# CZ     Manufacture of office machinery and computers (30)                                                  0
# DE     Manufacture of office machinery and computers (30)                                                  0
# DK     Manufacture of office machinery and computers (30)                                                  0
# EE     Manufacture of office machinery and computers (30)                                                  0
# ES     Manufacture of office machinery and computers (30)                                                  0
# FI     Manufacture of office machinery and computers (30)                                                  0
# FR     Manufacture of office machinery and computers (30)                                                  0
# GB     Manufacture of office machinery and computers (30)                                                  0
# GR     Manufacture of office machinery and computers (30)                                                  0
# HR     Manufacture of office machinery and computers (30)                                                  0
# HU     Manufacture of office machinery and computers (30)                                                  0
# ID     Manufacture of office machinery and computers (30)                                                  0
# IE     Manufacture of office machinery and computers (30)                                                  0
# IN     Manufacture of office machinery and computers (30)                                                  0
# IT     Manufacture of office machinery and computers (30)                                                  0
# JP     Manufacture of office machinery and computers (30)                                                  0
# KR     Manufacture of office machinery and computers (30)                                                  0
# LT     Manufacture of office machinery and computers (30)                                                  0
# LU     Manufacture of office machinery and computers (30)                                                  0
# LV     Manufacture of office machinery and computers (30)                                                  0
# MT     Manufacture of office machinery and computers (30)                                                  0
# MX     Manufacture of office machinery and computers (30)                                                  0
# NL     Manufacture of office machinery and computers (30)                                                  0
# NO     Manufacture of office machinery and computers (30)                                                  0
# PL     Manufacture of office machinery and computers (30)                                                  0
# PT     Manufacture of office machinery and computers (30)                                                  0
# RO     Manufacture of office machinery and computers (30)                                                  0
# RU     Manufacture of office machinery and computers (30)                                                  0
# SE     Manufacture of office machinery and computers (30)                                                  0
# SI     Manufacture of office machinery and computers (30)                                                  0
# SK     Manufacture of office machinery and computers (30)                                                  0
# TR     Manufacture of office machinery and computers (30)                                                  0
# TW     Manufacture of office machinery and computers (30)                                                  0
# US     Manufacture of office machinery and computers (30)                                                  0
# ZA     Manufacture of office machinery and computers (30)                                                  0
#
#                                                            (AU, Manufacture of office machinery and computers (30))  \
# region sector
# AT     Manufacture of office machinery and computers (30)                                           0.082894
# AU     Manufacture of office machinery and computers (30)                                           8.578719
# BE     Manufacture of office machinery and computers (30)                                           0.062994
# BG     Manufacture of office machinery and computers (30)                                           0.008170
# BR     Manufacture of office machinery and computers (30)                                           0.001788
# CA     Manufacture of office machinery and computers (30)                                           0.250911
# CH     Manufacture of office machinery and computers (30)                                           0.356634
# CN     Manufacture of office machinery and computers (30)                                          75.189220
# CY     Manufacture of office machinery and computers (30)                                           0.000000
# CZ     Manufacture of office machinery and computers (30)                                           0.026994
# DE     Manufacture of office machinery and computers (30)                                           0.811886
# DK     Manufacture of office machinery and computers (30)                                           0.005989
# EE     Manufacture of office machinery and computers (30)                                           0.000140
# ES     Manufacture of office machinery and computers (30)                                           0.031939
# FI     Manufacture of office machinery and computers (30)                                           0.043613
# FR     Manufacture of office machinery and computers (30)                                           0.834705
# GB     Manufacture of office machinery and computers (30)                                           0.159882
# GR     Manufacture of office machinery and computers (30)                                           0.000862
# HR     Manufacture of office machinery and computers (30)                                           0.000067
# HU     Manufacture of office machinery and computers (30)                                           1.121327
# ID     Manufacture of office machinery and computers (30)                                           0.285577
# IE     Manufacture of office machinery and computers (30)                                           4.284221
# IN     Manufacture of office machinery and computers (30)                                           0.034285
# IT     Manufacture of office machinery and computers (30)                                           0.087716
# JP     Manufacture of office machinery and computers (30)                                           1.276944
# KR     Manufacture of office machinery and computers (30)                                           1.201455
# LT     Manufacture of office machinery and computers (30)                                           0.000296
# LU     Manufacture of office machinery and computers (30)                                           0.001860
# LV     Manufacture of office machinery and computers (30)                                           0.012423
# MT     Manufacture of office machinery and computers (30)                                           0.000149
# MX     Manufacture of office machinery and computers (30)                                           1.057080
# NL     Manufacture of office machinery and computers (30)                                           0.062525
# NO     Manufacture of office machinery and computers (30)                                           0.015694
# ...
# BE     Manufacture of office machinery and computers (30)                                           0.000813
# BG     Manufacture of office machinery and computers (30)                                           0.000146
# BR     Manufacture of office machinery and computers (30)                                           0.000559
# CA     Manufacture of office machinery and computers (30)                                           0.003254
# CH     Manufacture of office machinery and computers (30)                                           0.002096
# CN     Manufacture of office machinery and computers (30)                                           0.387847
# CY     Manufacture of office machinery and computers (30)                                           0.000000
# CZ     Manufacture of office machinery and computers (30)                                           0.000422
# DE     Manufacture of office machinery and computers (30)                                           0.014331
# DK     Manufacture of office machinery and computers (30)                                           0.000464
# EE     Manufacture of office machinery and computers (30)                                           0.000098
# ES     Manufacture of office machinery and computers (30)                                           0.000337
# FI     Manufacture of office machinery and computers (30)                                           0.002005
# FR     Manufacture of office machinery and computers (30)                                           0.005159
# GB     Manufacture of office machinery and computers (30)                                           0.028208
# GR     Manufacture of office machinery and computers (30)                                           0.000018
# HR     Manufacture of office machinery and computers (30)                                           0.000022
# HU     Manufacture of office machinery and computers (30)                                           0.009461
# ID     Manufacture of office machinery and computers (30)                                           0.001243
# IE     Manufacture of office machinery and computers (30)                                           0.016813
# IN     Manufacture of office machinery and computers (30)                                           8.432234
# IT     Manufacture of office machinery and computers (30)                                           0.001469
# JP     Manufacture of office machinery and computers (30)                                           0.003599
# KR     Manufacture of office machinery and computers (30)                                           0.011189
# LT     Manufacture of office machinery and computers (30)                                           0.000084
# LU     Manufacture of office machinery and computers (30)                                           0.000036
# LV     Manufacture of office machinery and computers (30)                                           0.000232
# MT     Manufacture of office machinery and computers (30)                                           0.000002
# MX     Manufacture of office machinery and computers (30)                                           0.004058
# NL     Manufacture of office machinery and computers (30)                                           0.000748
# NO     Manufacture of office machinery and computers (30)                                           0.000114
# PL     Manufacture of office machinery and computers (30)                                           0.000271
# PT     Manufacture of office machinery and computers (30)                                           0.000377
# RO     Manufacture of office machinery and computers (30)                                           0.000148
# RU     Manufacture of office machinery and computers (30)                                           0.004625
# SE     Manufacture of office machinery and computers (30)                                           0.001435
# SI     Manufacture of office machinery and computers (30)                                           0.000316
# SK     Manufacture of office machinery and computers (30)                                           0.000115
# TR     Manufacture of office machinery and computers (30)                                           0.000122
# TW     Manufacture of office machinery and computers (30)                                           0.032174
# US     Manufacture of office machinery and computers (30)                                           0.068921
# ZA     Manufacture of office machinery and computers (30)                                           0.000416
#
#                                                            (SE, Manufacture of office machinery and computers (30))  \
# region sector
# AT     Manufacture of office machinery and computers (30)                                       1.052195e-03
# AU     Manufacture of office machinery and computers (30)                                       1.869229e-04
# BE     Manufacture of office machinery and computers (30)                                       7.137261e-03
# BG     Manufacture of office machinery and computers (30)                                       4.681031e-04
# BR     Manufacture of office machinery and computers (30)                                       1.136292e-04
# CA     Manufacture of office machinery and computers (30)                                       4.944543e-03
# CH     Manufacture of office machinery and computers (30)                                       1.141672e-03
# CN     Manufacture of office machinery and computers (30)                                       0.000000e+00
# CY     Manufacture of office machinery and computers (30)                                       0.000000e+00
# CZ     Manufacture of office machinery and computers (30)                                       4.566313e-03
# DE     Manufacture of office machinery and computers (30)                                       4.694236e-03
# DK     Manufacture of office machinery and computers (30)                                       1.862996e-02
# EE     Manufacture of office machinery and computers (30)                                       7.197637e-06
# ES     Manufacture of office machinery and computers (30)                                       4.986426e-04
# FI     Manufacture of office machinery and computers (30)                                       1.194045e-04
# FR     Manufacture of office machinery and computers (30)                                       0.000000e+00
# GB     Manufacture of office machinery and computers (30)                                       6.181654e-01
# GR     Manufacture of office machinery and computers (30)                                       8.387488e-07
# HR     Manufacture of office machinery and computers (30)                                       7.542959e-06
# HU     Manufacture of office machinery and computers (30)                                       1.215501e-02
# ID     Manufacture of office machinery and computers (30)                                       0.000000e+00
# IE     Manufacture of office machinery and computers (30)                                       2.947311e-01
# IN     Manufacture of office machinery and computers (30)                                       1.445784e-05
# IT     Manufacture of office machinery and computers (30)                                       4.436675e-03
# JP     Manufacture of office machinery and computers (30)                                       0.000000e+00
# KR     Manufacture of office machinery and computers (30)                                       0.000000e+00
# LT     Manufacture of office machinery and computers (30)                                       2.513367e-05
# LU     Manufacture of office machinery and computers (30)                                       5.714093e-04
# LV     Manufacture of office machinery and computers (30)                                       4.334373e-05
# MT     Manufacture of office machinery and computers (30)                                       1.214002e-06
# MX     Manufacture of office machinery and computers (30)                                       8.092415e-05
# NL     Manufacture of office machinery and computers (30)                                       3.333392e-03
# NO     Manufacture of office machinery and computers (30)                                       4.580829e-07
# PL     Manufacture of office machinery and computers (30)                                       1.198950e-03
# PT     Manufacture of office machinery and computers (30)                                       1.161701e-05
# RO     Manufacture of office machinery and computers (30)                                       0.000000e+00
# RU     Manufacture of office machinery and computers (30)                                       1.201134e-06
# SE     Manufacture of office machinery and computers (30)                                       1.235471e-01
# SI     Manufacture of office machinery and computers (30)                                       7.715827e-05
# SK     Manufacture of office machinery and computers (30)                                       2.596235e-02
# TR     Manufacture of office machinery and computers (30)                                       3.124937e-03
# TW     Manufacture of office machinery and computers (30)                                       0.000000e+00
# US     Manufacture of office machinery and computers (30)                                       2.139207e-02
# ZA     Manufacture of office machinery and computers (30)                                       3.485765e-04
#
#                                                            (FI, Manufacture of office machinery and computers (30))
# region sector
# AT     Manufacture of office machinery and computers (30)                                           0.025258
# AU     Manufacture of office machinery and computers (30)                                           0.027515
# BE     Manufacture of office machinery and computers (30)                                           0.280513
# BG     Manufacture of office machinery and computers (30)                                           0.006872
# BR     Manufacture of office machinery and computers (30)                                           0.001129
# CA     Manufacture of office machinery and computers (30)                                           0.123231
# CH     Manufacture of office machinery and computers (30)                                           0.274108
# CN     Manufacture of office machinery and computers (30)                                          28.525470
# CY     Manufacture of office machinery and computers (30)                                           0.000000
# CZ     Manufacture of office machinery and computers (30)                                           3.908929
# DE     Manufacture of office machinery and computers (30)                                           7.844787
# DK     Manufacture of office machinery and computers (30)                                           0.080272
# EE     Manufacture of office machinery and computers (30)                                           0.507339
# ES     Manufacture of office machinery and computers (30)                                           0.020152
# FI     Manufacture of office machinery and computers (30)                                           1.087241
# FR     Manufacture of office machinery and computers (30)                                           0.682674
# GB     Manufacture of office machinery and computers (30)                                           0.397740
# GR     Manufacture of office machinery and computers (30)                                           0.000761
# HR     Manufacture of office machinery and computers (30)                                           0.000050
# HU     Manufacture of office machinery and computers (30)                                           1.124607
# ID     Manufacture of office machinery and computers (30)                                           0.036490
# IE     Manufacture of office machinery and computers (30)                                          10.938507
# IN     Manufacture of office machinery and computers (30)                                           0.014226
# IT     Manufacture of office machinery and computers (30)                                           0.084743
# JP     Manufacture of office machinery and computers (30)                                           0.066268
# KR     Manufacture of office machinery and computers (30)                                           0.143902
# LT     Manufacture of office machinery and computers (30)                                           0.018281
# LU     Manufacture of office machinery and computers (30)                                           0.000213
# LV     Manufacture of office machinery and computers (30)                                           0.018480
# MT     Manufacture of office machinery and computers (30)                                           0.000202
# MX     Manufacture of office machinery and computers (30)                                           0.030832
# NL     Manufacture of office machinery and computers (30)                                           0.915784
# NO     Manufacture of office machinery and computers (30)                                           0.075613
# PL     Manufacture of office machinery and computers (30)                                           0.354275
# PT     Manufacture of office machinery and computers (30)                                           0.049386
# RO     Manufacture of office machinery and computers (30)                                           0.000055
# RU     Manufacture of office machinery and computers (30)                                           0.023440
# SE     Manufacture of office machinery and computers (30)                                           3.185085
# SI     Manufacture of office machinery and computers (30)                                           0.002845
# SK     Manufacture of office machinery and computers (30)                                           0.003402
# TR     Manufacture of office machinery and computers (30)                                           0.001220
# TW     Manufacture of office machinery and computers (30)                                           1.134930
# US     Manufacture of office machinery and computers (30)                                           4.989207
# ZA     Manufacture of office machinery and computers (30)                                           0.008073
#
# [44 rows x 41 columns]
